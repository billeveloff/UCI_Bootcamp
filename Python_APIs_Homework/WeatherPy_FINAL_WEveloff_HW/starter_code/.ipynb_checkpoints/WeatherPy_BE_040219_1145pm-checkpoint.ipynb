# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
# import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
print(lat_lngs)
# Out:
# <zip object at 0x000002F20215B148>

# %%
len(lats)
# Out:
# 1500

# %%
len(lngs)
# Out:
# 1500

# %%
coordinates_df = pd.DataFrame({'Latitude': lats, 'Longitude': lngs})
coordinates_df.tail()
# Out:
#        Latitude  Longitude
# 1495  19.418036  98.270909
# 1496  68.197432  19.459578
# 1497 -48.650390 -54.545147
# 1498 -77.064263  84.243998
# 1499  -3.737589  31.769294

# %%
cities_df = pd.DataFrame({'City': cities})
cities_df.tail()
# Out:
#              City
# 607         yomou
# 608  mae hong son
# 609        kiruna
# 610      necochea
# 611     ushirombo

# %%
cities_weather = cities_df.copy()
cities_weather.head()
# Out:
#           City
# 0        baker
# 1    marystown
# 2  barentsburg
# 3      rikitea
# 4      ushuaia

# %%
#setting up additional columns in dataframe
cities_weather ['Country'] = ""
cities_weather ['Date'] = ""
cities_weather ['Latitude'] = ""
cities_weather ['Longitude'] = ""
cities_weather ['Cloudiness'] = ""
cities_weather ['Max_Temp'] = ""
cities_weather ['Humidity'] = ""
cities_weather ['Wind_Speed'] = ""

cities_weather.head()
# Out:
#           City Country Date Latitude Longitude Cloudiness Max_Temp Humidity  \
# 0        baker
# 1    marystown
# 2  barentsburg
# 3      rikitea
# 4      ushuaia
#
#   Wind_Speed
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# import openweathermapy.core as owm
# Base url and define units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Query url
query_url = f"{url}appid={api_key}&units={units}&q="

# use iterrows to iterate through pandas dataframe
for index, row in cities_weather.iterrows():
    print(index)

    cityrow = row['City']
    
    try:
        response = requests.get(query_url + cityrow).json()
        pprint(response)

        results = response

        cities_weather.loc[index, 'Country'] = results['sys']['country']
        cities_weather.loc[index, 'Date'] = results['dt']
        cities_weather.loc[index, 'Latitude'] = results['coord']['lat']
        cities_weather.loc[index, 'Longitude'] = results['coord']['lon']
        cities_weather.loc[index, 'Cloudiness'] = results['clouds']['all']
        cities_weather.loc[index, 'Max_Temp'] = results['main']['temp_max']
        cities_weather.loc[index, 'Humidity'] = results['main']['humidity']
        cities_weather.loc[index, 'Wind_Speed'] = results['wind']['speed']
        print()
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
        print("------------")
# Out:
# 0
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 46.37, 'lon': -104.28},
#  'dt': 1554268500,
#  'id': 5638252,
#  'main': {'humidity': 74,
#           'pressure': 1016,
#           'temp': 28.4,
#           'temp_max': 28.4,
#           'temp_min': 28.4},
#  'name': 'Baker',
#  'sys': {'country': 'US',
#          'id': 3435,
#          'message': 0.0041,
#          'sunrise': 1554208495,
#          'sunset': 1554254770,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210, 'speed': 3.36}}
#
# 1
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 47.17, 'lon': -55.16},
#  'dt': 1554270367,
#  'id': 6067472,
#  'main': {'humidity': 100,
#           'pressure': 1039,
#           'temp': 28.99,
#           'temp_max': 28.99,
#           'temp_min': 28.99},
#  'name': 'Marystown',
#  'rain': {},
#  'snow': {},
#  'sys': {'country': 'CA',
#          'id': 61439,
#          'message': 0.0042,
#          'sunrise': 1554282964,
#          'sunset': 1554329493,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210.5, 'speed': 11.54}}
#
# 2
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 3
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1554270464,
#  'id': 4030556,
#  'main': {'grnd_level': 1018.81,
#           'humidity': 100,
#           'pressure': 1018.89,
#           'sea_level': 1018.89,
#           'temp': 75.37,
#           'temp_max': 75.37,
#           'temp_min': 75.37},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0083,
#          'sunrise': 1554217689,
#          'sunset': 1554260304},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 142.5, 'speed': 16.91}}
#
# 4
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1554267600,
#  'id': 3833367,
#  'main': {'humidity': 93,
#           'pressure': 984,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0226,
#          'sunrise': 1554289240,
#          'sunset': 1554329528,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 4.7}}
#
# 5
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -13.74, 'lon': -72.9},
#  'dt': 1554270626,
#  'id': 3948642,
#  'main': {'grnd_level': 663.93,
#           'humidity': 97,
#           'pressure': 1013.13,
#           'sea_level': 1013.13,
#           'temp': 38.29,
#           'temp_max': 38.29,
#           'temp_min': 38.29},
#  'name': 'Matara',
#  'sys': {'country': 'PE',
#          'message': 0.0039,
#          'sunrise': 1554288990,
#          'sunset': 1554331980},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 185, 'speed': 2.04}}
#
# 6
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1554267000,
#  'id': 3424607,
#  'main': {'humidity': 93,
#           'pressure': 996,
#           'temp': 32,
#           'temp_max': 32,
#           'temp_min': 32},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'message': 0.0043,
#          'sunrise': 1554277125,
#          'sunset': 1554326923,
#          'type': 1},
#  'weather': [{'description': 'heavy snow',
#               'icon': '13n',
#               'id': 602,
#               'main': 'Snow'}],
#  'wind': {'deg': 100, 'gust': 27.3, 'speed': 46.08}}
#
# 7
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1554270350,
#  'id': 964432,
#  'main': {'humidity': 92,
#           'pressure': 1015,
#           'temp': 62.01,
#           'temp_max': 62.01,
#           'temp_min': 62.01},
#  'name': 'Port Alfred',
#  'rain': {},
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'message': 0.0032,
#          'sunrise': 1554265527,
#          'sunset': 1554307553,
#          'type': 3},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 51.5, 'speed': 21.39}}
#
# 8
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1554270501,
#  'id': 4020109,
#  'main': {'grnd_level': 1012.81,
#           'humidity': 100,
#           'pressure': 1012.81,
#           'sea_level': 1012.81,
#           'temp': 81.85,
#           'temp_max': 81.85,
#           'temp_min': 81.85},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0041,
#          'sunrise': 1554218374,
#          'sunset': 1554261567},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 105, 'speed': 12.77}}
#
# 9
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1554270262,
#  'id': 2069194,
#  'main': {'grnd_level': 965.69,
#           'humidity': 40,
#           'pressure': 1023.13,
#           'sea_level': 1023.13,
#           'temp': 77.08,
#           'temp_max': 77.08,
#           'temp_min': 77.08},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0033,
#          'sunrise': 1554238693,
#          'sunset': 1554280778},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 128, 'speed': 5.95}}
#
# 10
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 46.85, 'lon': -1.88},
#  'dt': 1554270780,
#  'id': 3027513,
#  'main': {'humidity': 93,
#           'pressure': 1003,
#           'temp': 38.25,
#           'temp_max': 43,
#           'temp_min': 35.6},
#  'name': 'Challans',
#  'sys': {'country': 'FR',
#          'id': 6574,
#          'message': 0.0029,
#          'sunrise': 1554270211,
#          'sunset': 1554316676,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 5.82}}
#
# 11
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.08},
#  'dt': 1554270286,
#  'id': 1282256,
#  'main': {'grnd_level': 1011.85,
#           'humidity': 100,
#           'pressure': 1011.89,
#           'sea_level': 1011.89,
#           'temp': 84.73,
#           'temp_max': 84.73,
#           'temp_min': 84.73},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV',
#          'message': 0.0032,
#          'sunrise': 1554253670,
#          'sunset': 1554297244},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 309, 'speed': 9.75}}
#
# 12
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1554270450,
#  'id': 5855927,
#  'main': {'humidity': 78,
#           'pressure': 1019,
#           'temp': 69.3,
#           'temp_max': 75,
#           'temp_min': 66},
#  'name': 'Hilo',
#  'rain': {'1h': 1.52},
#  'sys': {'country': 'US',
#          'id': 7881,
#          'message': 0.0041,
#          'sunrise': 1554221580,
#          'sunset': 1554266064,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 30, 'speed': 12.75}}
#
# 13
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1554270006,
#  'id': 6201424,
#  'main': {'humidity': 67,
#           'pressure': 1025,
#           'temp': 57,
#           'temp_max': 57,
#           'temp_min': 57},
#  'name': 'Mataura',
#  'rain': {},
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0037,
#          'sunrise': 1554231846,
#          'sunset': 1554273103,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 209, 'gust': 4.02, 'speed': 3}}
#
# 14
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -8.83, 'lon': 13.24},
#  'dt': 1554267600,
#  'id': 2240449,
#  'main': {'humidity': 94,
#           'pressure': 1009,
#           'temp': 75.2,
#           'temp_max': 75.2,
#           'temp_min': 75.2},
#  'name': 'Luanda',
#  'sys': {'country': 'AO',
#          'id': 2173,
#          'message': 0.0037,
#          'sunrise': 1554268207,
#          'sunset': 1554311424,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 3.36}}
#
# 15
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 71.97, 'lon': 114.09},
#  'dt': 1554270488,
#  'id': 2017155,
#  'main': {'grnd_level': 991.21,
#           'humidity': 100,
#           'pressure': 1002.73,
#           'sea_level': 1002.73,
#           'temp': 30.64,
#           'temp_max': 30.64,
#           'temp_min': 30.64},
#  'name': 'Saskylakh',
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1554239535,
#          'sunset': 1554291698},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 114.5, 'speed': 4.61}}
#
# 16
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 17
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1554270346,
#  'id': 3985710,
#  'main': {'humidity': 40,
#           'pressure': 1017,
#           'temp': 68.4,
#           'temp_max': 73.4,
#           'temp_min': 61},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 7151,
#          'message': 0.0042,
#          'sunrise': 1554210665,
#          'sunset': 1554255302,
#          'type': 1},
#  'visibility': 11265,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 11.41}}
#
# 18
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 11.67, 'lon': 92.75},
#  'dt': 1554270540,
#  'id': 1259385,
#  'main': {'grnd_level': 1011.85,
#           'humidity': 100,
#           'pressure': 1012.13,
#           'sea_level': 1012.13,
#           'temp': 84.82,
#           'temp_max': 84.82,
#           'temp_min': 84.82},
#  'name': 'Port Blair',
#  'sys': {'country': 'IN',
#          'message': 0.0035,
#          'sunrise': 1554248679,
#          'sunset': 1554292795},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80.5, 'speed': 5.95}}
#
# 19
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 20
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1554270364,
#  'id': 2075265,
#  'main': {'humidity': 31,
#           'pressure': 1008,
#           'temp': 78.3,
#           'temp_max': 80.01,
#           'temp_min': 75.99},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'message': 0.0034,
#          'sunrise': 1554244288,
#          'sunset': 1554286341,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 46, 'speed': 5.5}}
#
# 21
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 16.86, 'lon': -99.88},
#  'dt': 1554266940,
#  'id': 3533462,
#  'main': {'humidity': 83,
#           'pressure': 1016,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Acapulco',
#  'sys': {'country': 'MX',
#          'id': 7103,
#          'message': 0.0036,
#          'sunrise': 1554208409,
#          'sunset': 1554252745,
#          'type': 1},
#  'visibility': 8047,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 4.7}}
#
# 22
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1554270228,
#  'id': 6185377,
#  'main': {'humidity': 70,
#           'pressure': 1021,
#           'temp': 0.79,
#           'temp_max': 1.4,
#           'temp_min': -0.01},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'message': 0.0044,
#          'sunrise': 1554209727,
#          'sunset': 1554258385,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 8.05}}
#
# 23
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.48, 'lon': -73.76},
#  'dt': 1554267600,
#  'id': 3896218,
#  'main': {'humidity': 100,
#           'pressure': 1019,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Castro',
#  'sys': {'country': 'CL',
#          'id': 8512,
#          'message': 0.0044,
#          'sunrise': 1554289984,
#          'sunset': 1554331398,
#          'type': 1},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 5.82}}
#
# 24
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 64.25, 'lon': -15.21},
#  'dt': 1554270563,
#  'id': 2630299,
#  'main': {'grnd_level': 1012.41,
#           'humidity': 100,
#           'pressure': 1023.73,
#           'sea_level': 1023.73,
#           'temp': 26.68,
#           'temp_max': 26.68,
#           'temp_min': 26.68},
#  'name': 'Hofn',
#  'sys': {'country': 'IS',
#          'message': 0.0034,
#          'sunrise': 1554271952,
#          'sunset': 1554321333},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 359, 'speed': 1.7}}
#
# 25
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.38, 'lon': 148.01},
#  'dt': 1554270513,
#  'id': 2166368,
#  'main': {'humidity': 30,
#           'pressure': 1024,
#           'temp': 81,
#           'temp_max': 81,
#           'temp_min': 81},
#  'name': 'Forbes',
#  'sys': {'country': 'AU',
#          'id': 20556,
#          'message': 0.0034,
#          'sunrise': 1554236438,
#          'sunset': 1554278517,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 158, 'speed': 4.5}}
#
# 26
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.27, 'lon': -76.89},
#  'dt': 1554270794,
#  'id': 5192726,
#  'main': {'humidity': 80,
#           'pressure': 1018,
#           'temp': 34.66,
#           'temp_max': 39.2,
#           'temp_min': 30},
#  'name': 'Harrisburg',
#  'sys': {'country': 'US',
#          'id': 3751,
#          'message': 0.0068,
#          'sunrise': 1554288500,
#          'sunset': 1554334384,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 4.7}}
#
# 27
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 69.7, 'lon': 170.27},
#  'dt': 1554270474,
#  'id': 2122090,
#  'main': {'grnd_level': 1017.69,
#           'humidity': 66,
#           'pressure': 1025.09,
#           'sea_level': 1025.09,
#           'temp': 23.08,
#           'temp_max': 23.08,
#           'temp_min': 23.08},
#  'name': 'Pevek',
#  'sys': {'country': 'RU',
#          'message': 0.003,
#          'sunrise': 1554226642,
#          'sunset': 1554277631},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 127, 'speed': 6.4}}
#
# 28
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 16.12, 'lon': 74.21},
#  'dt': 1554267600,
#  'id': 1279154,
#  'main': {'humidity': 15,
#           'pressure': 1017,
#           'temp': 91.4,
#           'temp_max': 91.4,
#           'temp_min': 91.4},
#  'name': 'Ajra',
#  'sys': {'country': 'IN',
#          'id': 9229,
#          'message': 0.0034,
#          'sunrise': 1554253021,
#          'sunset': 1554297351,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 50, 'speed': 6.93}}
#
# 29
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1554270468,
#  'id': 3833859,
#  'main': {'grnd_level': 1004.41,
#           'humidity': 91,
#           'pressure': 1016.33,
#           'sea_level': 1016.33,
#           'temp': 52.51,
#           'temp_max': 52.51,
#           'temp_min': 52.51},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.003,
#          'sunrise': 1554286592,
#          'sunset': 1554328298},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 212, 'speed': 5.06}}
#
# 30
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -45.58, 'lon': -72.07},
#  'dt': 1554267600,
#  'id': 3894426,
#  'main': {'humidity': 54,
#           'pressure': 1013,
#           'temp': 50.56,
#           'temp_max': 53.6,
#           'temp_min': 48.2},
#  'name': 'Coihaique',
#  'sys': {'country': 'CL',
#          'id': 8491,
#          'message': 0.0045,
#          'sunrise': 1554289697,
#          'sunset': 1554330874,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'gust': 9.8, 'speed': 10.29}}
#
# 31
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -20.68, 'lon': 164.93},
#  'dt': 1554271016,
#  'id': 2141050,
#  'main': {'grnd_level': 1004.81,
#           'humidity': 100,
#           'pressure': 1012.21,
#           'sea_level': 1012.21,
#           'temp': 79.15,
#           'temp_max': 79.15,
#           'temp_min': 79.15},
#  'name': 'Hienghene',
#  'sys': {'country': 'NC',
#          'message': 0.0032,
#          'sunrise': 1554232060,
#          'sunset': 1554274775},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 104, 'speed': 13.22}}
#
# 32
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 35.03, 'lon': 71.36},
#  'dt': 1554271016,
#  'id': 1148205,
#  'main': {'grnd_level': 863.93,
#           'humidity': 23,
#           'pressure': 1012.29,
#           'sea_level': 1012.29,
#           'temp': 76.45,
#           'temp_max': 76.45,
#           'temp_min': 76.45},
#  'name': 'Asmar',
#  'sys': {'country': 'AF',
#          'message': 0.0034,
#          'sunrise': 1554253159,
#          'sunset': 1554298580},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 69, 'speed': 2.59}}
#
# 33
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 69.38, 'lon': 178.42},
#  'dt': 1554270517,
#  'id': 2123814,
#  'main': {'grnd_level': 1025.85,
#           'humidity': 86,
#           'pressure': 1028.73,
#           'sea_level': 1028.73,
#           'temp': 18.13,
#           'temp_max': 18.13,
#           'temp_min': 18.13},
#  'name': 'Leningradskiy',
#  'sys': {'country': 'RU',
#          'message': 0.0037,
#          'sunrise': 1554224759,
#          'sunset': 1554275603},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 118.5, 'speed': 21.27}}
#
# 34
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1554270426,
#  'id': 5848280,
#  'main': {'humidity': 69,
#           'pressure': 1021,
#           'temp': 72.45,
#           'temp_max': 75.2,
#           'temp_min': 70},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 7873,
#          'message': 0.0041,
#          'sunrise': 1554222536,
#          'sunset': 1554267143,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 13.87}}
#
# 35
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1554270466,
#  'id': 2110227,
#  'main': {'grnd_level': 1010.41,
#           'humidity': 100,
#           'pressure': 1010.57,
#           'sea_level': 1010.57,
#           'temp': 76,
#           'temp_max': 76,
#           'temp_min': 76},
#  'name': 'Butaritari',
#  'rain': {'3h': 10.975},
#  'sys': {'country': 'KI',
#          'message': 0.0031,
#          'sunrise': 1554229667,
#          'sunset': 1554273397},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 187, 'speed': 5.61}}
#
# 36
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 47.85, 'lon': -83.4},
#  'dt': 1554271017,
#  'id': 5919915,
#  'main': {'grnd_level': 951.05,
#           'humidity': 86,
#           'pressure': 1003.45,
#           'sea_level': 1003.45,
#           'temp': 32.35,
#           'temp_max': 32.35,
#           'temp_min': 32.35},
#  'name': 'Chapleau',
#  'sys': {'country': 'CA',
#          'message': 0.0036,
#          'sunrise': 1554289695,
#          'sunset': 1554336314},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 235, 'speed': 8.19}}
#
# 37
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1554267600,
#  'id': 1273574,
#  'main': {'humidity': 15,
#           'pressure': 1017,
#           'temp': 86.83,
#           'temp_max': 91.4,
#           'temp_min': 82.4},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'id': 9229,
#          'message': 0.0033,
#          'sunrise': 1554252973,
#          'sunset': 1554297265,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 50, 'speed': 6.93}}
#
# 38
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1554270364,
#  'id': 3369157,
#  'main': {'humidity': 81,
#           'pressure': 1011,
#           'temp': 57.31,
#           'temp_max': 66,
#           'temp_min': 51.8},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'message': 0.0036,
#          'sunrise': 1554267571,
#          'sunset': 1554309575,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 4.7}}
#
# 39
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -3.41, 'lon': 114.85},
#  'dt': 1554269400,
#  'id': 1636022,
#  'main': {'humidity': 74,
#           'pressure': 1010,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Martapura',
#  'sys': {'country': 'ID',
#          'id': 9360,
#          'message': 0.0041,
#          'sunrise': 1554243707,
#          'sunset': 1554287162,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 6.93}}
#
# 40
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 27.87, 'lon': -0.29},
#  'dt': 1554267600,
#  'id': 2508813,
#  'main': {'humidity': 34,
#           'pressure': 1012,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Adrar',
#  'sys': {'country': 'DZ',
#          'id': 1098,
#          'message': 0.013,
#          'sunrise': 1554270573,
#          'sunset': 1554315551,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 11.41}}
#
# 41
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1554269400,
#  'id': 4035715,
#  'main': {'humidity': 78,
#           'pressure': 1010,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'message': 0.0053,
#          'sunrise': 1554223601,
#          'sunset': 1554266299,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 5.82}}
#
# 42
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1554270520,
#  'id': 3378644,
#  'main': {'grnd_level': 1012.33,
#           'humidity': 80,
#           'pressure': 1013.17,
#           'sea_level': 1013.17,
#           'temp': 75.01,
#           'temp_max': 75.01,
#           'temp_min': 75.01},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'message': 0.0038,
#          'sunrise': 1554284995,
#          'sunset': 1554328901},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 46, 'speed': 4.61}}
#
# 43
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -2.79, 'lon': 10.1},
#  'dt': 1554271019,
#  'id': 2400547,
#  'main': {'grnd_level': 1008.81,
#           'humidity': 100,
#           'pressure': 1009.29,
#           'sea_level': 1009.29,
#           'temp': 78.34,
#           'temp_max': 78.34,
#           'temp_min': 78.34},
#  'name': 'Tsogni',
#  'rain': {'3h': 11.03},
#  'sys': {'country': 'GA',
#          'message': 0.0041,
#          'sunrise': 1554268830,
#          'sunset': 1554312309},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 354.5, 'speed': 2.93}}
#
# 44
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 26.33, 'lon': 43.97},
#  'dt': 1554267600,
#  'id': 107304,
#  'main': {'humidity': 63,
#           'pressure': 1012,
#           'temp': 62.6,
#           'temp_max': 62.6,
#           'temp_min': 62.6},
#  'name': 'Buraydah',
#  'sys': {'country': 'SA',
#          'id': 7411,
#          'message': 0.0029,
#          'sunrise': 1554260004,
#          'sunset': 1554304880,
#          'type': 1},
#  'visibility': 7000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 3.36}}
#
# 45
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.42, 'lon': -6.55},
#  'dt': 1554270495,
#  'id': 2737599,
#  'main': {'grnd_level': 937.93,
#           'humidity': 92,
#           'pressure': 1013.01,
#           'sea_level': 1013.01,
#           'temp': 32.44,
#           'temp_max': 32.44,
#           'temp_min': 32.44},
#  'name': 'Saldanha',
#  'sys': {'country': 'PT',
#          'message': 0.0035,
#          'sunrise': 1554271589,
#          'sunset': 1554317539},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 288, 'speed': 4.5}}
#
# 46
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -0.86, 'lon': 131.25},
#  'dt': 1554270580,
#  'id': 1626542,
#  'main': {'grnd_level': 1005.85,
#           'humidity': 100,
#           'pressure': 1008.77,
#           'sea_level': 1008.77,
#           'temp': 81.94,
#           'temp_max': 81.94,
#           'temp_min': 81.94},
#  'name': 'Sorong',
#  'rain': {'3h': 2.25},
#  'sys': {'country': 'ID',
#          'message': 0.0043,
#          'sunrise': 1554239717,
#          'sunset': 1554283281},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 264.5, 'speed': 11.77}}
#
# 47
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1554270431,
#  'id': 3366880,
#  'main': {'humidity': 82,
#           'pressure': 1008,
#           'temp': 61.45,
#           'temp_max': 62.01,
#           'temp_min': 61},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'message': 0.0041,
#          'sunrise': 1554267388,
#          'sunset': 1554309364,
#          'type': 3},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 78, 'gust': 4.92, 'speed': 5.99}}
#
# 48
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 49
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 45.6, 'lon': -0.6},
#  'dt': 1554270428,
#  'id': 3026644,
#  'main': {'humidity': 87,
#           'pressure': 1006,
#           'temp': 41.94,
#           'temp_max': 44.01,
#           'temp_min': 39.99},
#  'name': 'Souillac',
#  'sys': {'country': 'FR',
#          'id': 6452,
#          'message': 0.0034,
#          'sunrise': 1554269968,
#          'sunset': 1554316305,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 280, 'speed': 19.46}}
#
# 50
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1554270471,
#  'id': 2175403,
#  'main': {'grnd_level': 993.21,
#           'humidity': 37,
#           'pressure': 1015.57,
#           'sea_level': 1015.57,
#           'temp': 86.44,
#           'temp_max': 86.44,
#           'temp_min': 86.44},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0031,
#          'sunrise': 1554235935,
#          'sunset': 1554278512},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 113, 'speed': 12.77}}
#
# 51
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 45.29, 'lon': 14.65},
#  'dt': 1554270983,
#  'id': 3191648,
#  'main': {'humidity': 87,
#           'pressure': 1012,
#           'temp': 49.78,
#           'temp_max': 53.6,
#           'temp_min': 46.99},
#  'name': 'Zlobin',
#  'sys': {'country': 'HR',
#          'id': 6385,
#          'message': 0.0099,
#          'sunrise': 1554266329,
#          'sunset': 1554312626,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 100, 'speed': 6.93}}
#
# 52
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.7, 'lon': -7.74},
#  'dt': 1554270903,
#  'id': 2732265,
#  'main': {'humidity': 92,
#           'pressure': 1013,
#           'temp': 43.84,
#           'temp_max': 46.99,
#           'temp_min': 42.01},
#  'name': 'Ladario',
#  'sys': {'country': 'PT',
#          'id': 2005661,
#          'message': 0.0034,
#          'sunrise': 1554271905,
#          'sunset': 1554317794,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 349, 'speed': 2.26}}
#
# 53
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -4.26, 'lon': -55.99},
#  'dt': 1554271021,
#  'id': 3397967,
#  'main': {'grnd_level': 1000.17,
#           'humidity': 93,
#           'pressure': 1010.01,
#           'sea_level': 1010.01,
#           'temp': 76.09,
#           'temp_max': 76.09,
#           'temp_min': 76.09},
#  'name': 'Itaituba',
#  'sys': {'country': 'BR',
#          'message': 0.0034,
#          'sunrise': 1554284721,
#          'sunset': 1554328134},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 85, 'speed': 3.04}}
#
# 54
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -19.06, 'lon': -169.92},
#  'dt': 1554267600,
#  'id': 4036284,
#  'main': {'humidity': 78,
#           'pressure': 1011,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Alofi',
#  'sys': {'country': 'NU',
#          'id': 7306,
#          'message': 0.0041,
#          'sunrise': 1554225987,
#          'sunset': 1554268779,
#          'type': 1},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 11.41}}
#
# 55
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 62.16, 'lon': 45.12},
#  'dt': 1554271022,
#  'id': 563990,
#  'main': {'grnd_level': 1011.05,
#           'humidity': 83,
#           'pressure': 1026.85,
#           'sea_level': 1026.85,
#           'temp': 33.16,
#           'temp_max': 33.16,
#           'temp_min': 33.16},
#  'name': 'Dvinskoy',
#  'sys': {'country': 'RU',
#          'message': 0.0035,
#          'sunrise': 1554257770,
#          'sunset': 1554306562},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 218, 'speed': 4.61}}
#
# 56
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 17.42, 'lon': -93.3},
#  'dt': 1554271022,
#  'id': 3522293,
#  'main': {'grnd_level': 952.33,
#           'humidity': 95,
#           'pressure': 1017.89,
#           'sea_level': 1017.89,
#           'temp': 67.45,
#           'temp_max': 67.45,
#           'temp_min': 67.45},
#  'name': 'Ostuacan',
#  'rain': {'3h': 0.74},
#  'sys': {'country': 'MX',
#          'message': 0.004,
#          'sunrise': 1554206817,
#          'sunset': 1554251179},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 253.5, 'speed': 2.04}}
#
# 57
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 58
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 59
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 30.82, 'lon': -88.07},
#  'dt': 1554270924,
#  'id': 4088628,
#  'main': {'humidity': 100,
#           'pressure': 1023,
#           'temp': 47.23,
#           'temp_max': 51.01,
#           'temp_min': 42.8},
#  'name': 'Saraland',
#  'sys': {'country': 'US',
#          'id': 3692,
#          'message': 0.0055,
#          'sunrise': 1554291531,
#          'sunset': 1554336719,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 31, 'speed': 6.51}}
#
# 60
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 61
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.28, 'lon': 82.18},
#  'dt': 1554270599,
#  'id': 1283285,
#  'main': {'grnd_level': 675.21,
#           'humidity': 71,
#           'pressure': 1010.17,
#           'sea_level': 1010.17,
#           'temp': 47.11,
#           'temp_max': 47.11,
#           'temp_min': 47.11},
#  'name': 'Jumla',
#  'sys': {'country': 'NP',
#          'message': 0.0039,
#          'sunrise': 1554250753,
#          'sunset': 1554295794},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 192, 'speed': 0.92}}
#
# 62
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1554270482,
#  'id': 3372707,
#  'main': {'grnd_level': 1027.21,
#           'humidity': 100,
#           'pressure': 1030.77,
#           'sea_level': 1030.77,
#           'temp': 58.36,
#           'temp_max': 58.36,
#           'temp_min': 58.36},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'message': 0.0037,
#          'sunrise': 1554277019,
#          'sunset': 1554322739},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30.5, 'speed': 14.79}}
#
# 63
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1554270423,
#  'id': 4407665,
#  'main': {'humidity': 35,
#           'pressure': 1020,
#           'temp': 45,
#           'temp_max': 46.99,
#           'temp_min': 42.8},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 4022,
#          'message': 0.0049,
#          'sunrise': 1554292798,
#          'sunset': 1554338663,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 5.82}}
#
# 64
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1554270340,
#  'id': 344979,
#  'main': {'grnd_level': 768.33,
#           'humidity': 62,
#           'pressure': 1011.49,
#           'sea_level': 1011.49,
#           'temp': 64.39,
#           'temp_max': 64.39,
#           'temp_min': 64.39},
#  'name': 'Lebu',
#  'sys': {'country': 'ET',
#          'message': 0.0041,
#          'sunrise': 1554261701,
#          'sunset': 1554305698},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27.5, 'speed': 2.71}}
#
# 65
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -0.39, 'lon': -78.55},
#  'dt': 1554270335,
#  'id': 3652462,
#  'main': {'humidity': 93,
#           'pressure': 1029,
#           'temp': 52.59,
#           'temp_max': 57.2,
#           'temp_min': 48.99},
#  'name': 'San Cristobal',
#  'sys': {'country': 'EC',
#          'id': 8555,
#          'message': 0.0047,
#          'sunrise': 1554290049,
#          'sunset': 1554333632,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 3.36}}
#
# 66
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 62.23, 'lon': -6.59},
#  'dt': 1554268800,
#  'id': 2618795,
#  'main': {'humidity': 80,
#           'pressure': 1015,
#           'temp': 35.6,
#           'temp_max': 35.6,
#           'temp_min': 35.6},
#  'name': 'Klaksvik',
#  'sys': {'country': 'FO',
#          'id': 1596,
#          'message': 0.0035,
#          'sunrise': 1554270144,
#          'sunset': 1554319004,
#          'type': 1},
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 350, 'gust': 16.5, 'speed': 25.28}}
#
# 67
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1554270526,
#  'id': 2022572,
#  'main': {'grnd_level': 1002.73,
#           'humidity': 94,
#           'pressure': 1007.41,
#           'sea_level': 1007.41,
#           'temp': 19.21,
#           'temp_max': 19.21,
#           'temp_min': 19.21},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU',
#          'message': 0.0036,
#          'sunrise': 1554242311,
#          'sunset': 1554294499},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 341, 'speed': 8.19}}
#
# 68
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 15.86, 'lon': -97.07},
#  'dt': 1554266700,
#  'id': 3520994,
#  'main': {'humidity': 69,
#           'pressure': 1020,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Puerto Escondido',
#  'sys': {'country': 'MX',
#          'id': 7157,
#          'message': 0.0036,
#          'sunrise': 1554207758,
#          'sunset': 1554252047,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 294, 'speed': 9.19}}
#
# 69
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -33.69, 'lon': -53.46},
#  'dt': 1554270541,
#  'id': 3443061,
#  'main': {'grnd_level': 1009.45,
#           'humidity': 98,
#           'pressure': 1010.85,
#           'sea_level': 1010.85,
#           'temp': 67,
#           'temp_max': 67,
#           'temp_min': 67},
#  'name': 'Chuy',
#  'rain': {'3h': 1.405},
#  'sys': {'country': 'UY',
#          'message': 0.0037,
#          'sunrise': 1554284824,
#          'sunset': 1554326817},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 198.5, 'speed': 15.57}}
#
# 70
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 10.52, 'lon': 10.33},
#  'dt': 1554271025,
#  'id': 2317887,
#  'main': {'grnd_level': 954.09,
#           'humidity': 30,
#           'pressure': 1008.93,
#           'sea_level': 1008.93,
#           'temp': 69.34,
#           'temp_max': 69.34,
#           'temp_min': 69.34},
#  'name': 'Bure',
#  'sys': {'country': 'NG',
#          'message': 0.0035,
#          'sunrise': 1554268478,
#          'sunset': 1554312549},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 22.5, 'speed': 5.95}}
#
# 71
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 65.58, 'lon': -170.99},
#  'dt': 1554270558,
#  'id': 4031637,
#  'main': {'grnd_level': 1017.93,
#           'humidity': 87,
#           'pressure': 1022.29,
#           'sea_level': 1022.29,
#           'temp': 22.45,
#           'temp_max': 22.45,
#           'temp_min': 22.45},
#  'name': 'Lavrentiya',
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1554309049,
#          'sunset': 1554358994},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 45, 'speed': 10.2}}
#
# 72
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 73.51, 'lon': 80.55},
#  'dt': 1554270475,
#  'id': 1507390,
#  'main': {'grnd_level': 1001.93,
#           'humidity': 100,
#           'pressure': 1002.37,
#           'sea_level': 1002.37,
#           'temp': 23.35,
#           'temp_max': 23.35,
#           'temp_min': 23.35},
#  'name': 'Dikson',
#  'sys': {'country': 'RU',
#          'message': 0.0042,
#          'sunrise': 1554247093,
#          'sunset': 1554300236},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210.5, 'speed': 19.26}}
#
# 73
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -22.45, 'lon': 18.97},
#  'dt': 1554271026,
#  'id': 3357247,
#  'main': {'grnd_level': 853.45,
#           'humidity': 84,
#           'pressure': 1014.29,
#           'sea_level': 1014.29,
#           'temp': 61.6,
#           'temp_max': 61.6,
#           'temp_min': 61.6},
#  'name': 'Gobabis',
#  'rain': {'3h': 0.455},
#  'sys': {'country': 'NA',
#          'message': 0.0044,
#          'sunrise': 1554267140,
#          'sunset': 1554309742},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 256.5, 'speed': 1.92}}
#
# 74
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 75
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 60.55, 'lon': -151.26},
#  'dt': 1554270966,
#  'id': 5866063,
#  'main': {'humidity': 59,
#           'pressure': 1010,
#           'temp': 36.59,
#           'temp_max': 37.4,
#           'temp_min': 34},
#  'name': 'Kenai',
#  'sys': {'country': 'US',
#          'id': 7680,
#          'message': 0.0035,
#          'sunrise': 1554218762,
#          'sunset': 1554267049,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 5.82}}
#
# 76
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1554270336,
#  'id': 546105,
#  'main': {'humidity': 48,
#           'pressure': 1028,
#           'temp': 36.19,
#           'temp_max': 39.2,
#           'temp_min': 34},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'message': 0.0032,
#          'sunrise': 1554261465,
#          'sunset': 1554309745,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 4.47}}
#
# 77
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1554267600,
#  'id': 4031574,
#  'main': {'humidity': 74,
#           'pressure': 1021,
#           'temp': 30.2,
#           'temp_max': 30.2,
#           'temp_min': 30.2},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'id': 8875,
#          'message': 0.0036,
#          'sunrise': 1554309758,
#          'sunset': 1554359360,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 17.9}}
#
# 78
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 54.11, 'lon': 102.18},
#  'dt': 1554271027,
#  'id': 2055166,
#  'main': {'grnd_level': 955.45,
#           'humidity': 38,
#           'pressure': 1017.09,
#           'sea_level': 1017.09,
#           'temp': 43.33,
#           'temp_max': 43.33,
#           'temp_min': 43.33},
#  'name': 'Sayansk',
#  'sys': {'country': 'RU',
#          'message': 0.0035,
#          'sunrise': 1554244832,
#          'sunset': 1554292117},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 308, 'speed': 16.8}}
#
# 79
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 60.53, 'lon': 8.21},
#  'dt': 1554270871,
#  'id': 3155913,
#  'main': {'humidity': 83,
#           'pressure': 1010,
#           'temp': 20.43,
#           'temp_max': 24.01,
#           'temp_min': 17.01},
#  'name': 'Geilo',
#  'snow': {'3h': 0.0075},
#  'sys': {'country': 'NO',
#          'id': 2002180,
#          'message': 0.0036,
#          'sunrise': 1554266788,
#          'sunset': 1554315257,
#          'type': 3},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 45, 'speed': 2.59}}
#
# 80
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 20.71, 'lon': -105.21},
#  'dt': 1554270321,
#  'id': 4004293,
#  'main': {'humidity': 88,
#           'pressure': 1017,
#           'temp': 75.11,
#           'temp_max': 75.2,
#           'temp_min': 75},
#  'name': 'Ixtapa',
#  'sys': {'country': 'MX',
#          'id': 7156,
#          'message': 0.0048,
#          'sunrise': 1554209593,
#          'sunset': 1554254118,
#          'type': 1},
#  'visibility': 19312,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 3.36}}
#
# 81
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
# ...
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 137.5, 'speed': 2.04}}
#
# 585
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 60.75, 'lon': -137.51},
#  'dt': 1554271163,
#  'id': 5969025,
#  'main': {'grnd_level': 879.29,
#           'humidity': 93,
#           'pressure': 1006.45,
#           'sea_level': 1006.45,
#           'temp': 27.76,
#           'temp_max': 27.76,
#           'temp_min': 27.76},
#  'name': 'Haines Junction',
#  'sys': {'country': 'CA',
#          'message': 0.0043,
#          'sunrise': 1554215449,
#          'sunset': 1554263763},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 252, 'speed': 2.59}}
#
# 586
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 39.77, 'lon': 98.29},
#  'dt': 1554271128,
#  'id': 1280957,
#  'main': {'grnd_level': 782.09,
#           'humidity': 70,
#           'pressure': 1015.33,
#           'sea_level': 1015.33,
#           'temp': 48.91,
#           'temp_max': 48.91,
#           'temp_min': 48.91},
#  'name': 'Jiayuguan',
#  'sys': {'country': 'CN',
#          'message': 0.0043,
#          'sunrise': 1554246525,
#          'sunset': 1554292291},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340.5, 'speed': 4.94}}
#
# 587
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -32.7, 'lon': -57.63},
#  'dt': 1554271164,
#  'id': 3439525,
#  'main': {'grnd_level': 1006.97,
#           'humidity': 94,
#           'pressure': 1012.85,
#           'sea_level': 1012.85,
#           'temp': 64.48,
#           'temp_max': 64.48,
#           'temp_min': 64.48},
#  'name': 'Young',
#  'rain': {'3h': 1.3},
#  'sys': {'country': 'UY',
#          'message': 0.004,
#          'sunrise': 1554285797,
#          'sunset': 1554327845},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 135.5, 'speed': 11.77}}
#
# 588
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 589
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 64.47, 'lon': 40.85},
#  'dt': 1554269400,
#  'id': 477579,
#  'main': {'humidity': 64,
#           'pressure': 1021,
#           'temp': 35.6,
#           'temp_max': 35.6,
#           'temp_min': 35.6},
#  'name': 'Uyemskiy',
#  'sys': {'country': 'RU',
#          'id': 8922,
#          'message': 0.0035,
#          'sunrise': 1554258501,
#          'sunset': 1554307880,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 6.71}}
#
# 590
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 50.23, 'lon': -63.6},
#  'dt': 1554267600,
#  'id': 5972291,
#  'main': {'humidity': 85,
#           'pressure': 1024,
#           'temp': 23,
#           'temp_max': 23,
#           'temp_min': 23},
#  'name': 'Havre-Saint-Pierre',
#  'sys': {'country': 'CA',
#          'id': 812,
#          'message': 0.0035,
#          'sunrise': 1554284811,
#          'sunset': 1554331696,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 9.17}}
#
# 591
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 58.89, 'lon': 5.65},
#  'dt': 1554271088,
#  'id': 3137942,
#  'main': {'humidity': 49,
#           'pressure': 1001,
#           'temp': 44.8,
#           'temp_max': 48.2,
#           'temp_min': 42.01},
#  'name': 'Sola',
#  'sys': {'country': 'NO',
#          'id': 1680,
#          'message': 0.0045,
#          'sunrise': 1554267564,
#          'sunset': 1554315710,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 17.22}}
#
# 592
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 15.65, 'lon': 120.33},
#  'dt': 1554267600,
#  'id': 1729510,
#  'main': {'humidity': 49,
#           'pressure': 1013,
#           'temp': 91.4,
#           'temp_max': 91.4,
#           'temp_min': 91.4},
#  'name': 'Bacsay',
#  'sys': {'country': 'PH',
#          'id': 8152,
#          'message': 0.0038,
#          'sunrise': 1554241970,
#          'sunset': 1554286269,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 2.24}}
#
# 593
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 53.59, 'lon': 25.82},
#  'dt': 1554271165,
#  'id': 624785,
#  'main': {'grnd_level': 1002.81,
#           'humidity': 58,
#           'pressure': 1026.73,
#           'sea_level': 1026.73,
#           'temp': 36.04,
#           'temp_max': 36.04,
#           'temp_min': 36.04},
#  'name': 'Navahrudak',
#  'sys': {'country': 'BY',
#          'message': 0.003,
#          'sunrise': 1554263164,
#          'sunset': 1554310430},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 132, 'speed': 11.77}}
#
# 594
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 34.7, 'lon': 138.93},
#  'dt': 1554270912,
#  'id': 1852357,
#  'main': {'humidity': 18,
#           'pressure': 1015,
#           'temp': 54.36,
#           'temp_max': 60.01,
#           'temp_min': 50},
#  'name': 'Shimoda',
#  'sys': {'country': 'JP',
#          'id': 7956,
#          'message': 0.0032,
#          'sunrise': 1554236970,
#          'sunset': 1554282343,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'gust': 12.9, 'speed': 10.29}}
#
# 595
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -35.17, 'lon': 173.16},
#  'dt': 1554271069,
#  'id': 2194098,
#  'main': {'grnd_level': 1008.33,
#           'humidity': 98,
#           'pressure': 1021.61,
#           'sea_level': 1021.61,
#           'temp': 64.21,
#           'temp_max': 64.21,
#           'temp_min': 64.21},
#  'name': 'Ahipara',
#  'rain': {'3h': 0.825},
#  'sys': {'country': 'NZ',
#          'message': 0.0039,
#          'sunrise': 1554230449,
#          'sunset': 1554272437},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 118, 'speed': 9.75}}
#
# 596
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 37.73, 'lon': -25.67},
#  'dt': 1554271160,
#  'id': 3372783,
#  'main': {'humidity': 76,
#           'pressure': 1028,
#           'temp': 55.18,
#           'temp_max': 55.4,
#           'temp_min': 55},
#  'name': 'Ponta Delgada',
#  'sys': {'country': 'PT',
#          'id': 6899,
#          'message': 0.0039,
#          'sunrise': 1554276324,
#          'sunset': 1554321981,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 10.29}}
#
# 597
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -7.47, 'lon': -34.81},
#  'dt': 1554267600,
#  'id': 3391889,
#  'main': {'humidity': 94,
#           'pressure': 1011,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Pitimbu',
#  'sys': {'country': 'BR',
#          'id': 8391,
#          'message': 0.004,
#          'sunrise': 1554279709,
#          'sunset': 1554322982,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 4.7}}
#
# 598
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -6.9, 'lon': 112.07},
#  'dt': 1554271166,
#  'id': 1623180,
#  'main': {'grnd_level': 1002.33,
#           'humidity': 85,
#           'pressure': 1009.57,
#           'sea_level': 1009.57,
#           'temp': 86.08,
#           'temp_max': 86.08,
#           'temp_min': 86.08},
#  'name': 'Tuban',
#  'sys': {'country': 'ID',
#          'message': 0.0033,
#          'sunrise': 1554244448,
#          'sunset': 1554287755},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 98, 'speed': 4.16}}
#
# 599
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 35.39, 'lon': -94.42},
#  'dt': 1554271161,
#  'id': 4111410,
#  'main': {'humidity': 87,
#           'pressure': 1022,
#           'temp': 47.75,
#           'temp_max': 53.6,
#           'temp_min': 42.01},
#  'name': 'Fort Smith',
#  'sys': {'country': 'US',
#          'id': 5672,
#          'message': 0.004,
#          'sunrise': 1554292895,
#          'sunset': 1554338402,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 172.5, 'speed': 3.71}}
#
# 600
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 601
# {'cod': '404', 'message': 'city not found'}
# City not found... skipping.
# ------------
# 602
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 8.2, 'lon': -59.78},
#  'dt': 1554271167,
#  'id': 3377301,
#  'main': {'grnd_level': 1011.85,
#           'humidity': 93,
#           'pressure': 1013.33,
#           'sea_level': 1013.33,
#           'temp': 73.84,
#           'temp_max': 73.84,
#           'temp_min': 73.84},
#  'name': 'Mabaruma',
#  'sys': {'country': 'GY',
#          'message': 0.0049,
#          'sunrise': 1554285352,
#          'sunset': 1554329322},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 85, 'speed': 5.17}}
#
# 603
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -39.94, 'lon': 176.59},
#  'dt': 1554270736,
#  'id': 2185329,
#  'main': {'humidity': 70,
#           'pressure': 1026,
#           'temp': 54,
#           'temp_max': 54,
#           'temp_min': 54},
#  'name': 'Waipawa',
#  'rain': {'3h': 0.075},
#  'sys': {'country': 'NZ',
#          'id': 2010964,
#          'message': 0.004,
#          'sunrise': 1554229770,
#          'sunset': 1554271470,
#          'type': 3},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 135, 'gust': 2.24, 'speed': 1.99}}
#
# 604
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -35.12, 'lon': 139.28},
#  'dt': 1554270970,
#  'id': 2065176,
#  'main': {'humidity': 40,
#           'pressure': 1022,
#           'temp': 73.65,
#           'temp_max': 75.99,
#           'temp_min': 72},
#  'name': 'Murray Bridge',
#  'sys': {'country': 'AU',
#          'id': 2005401,
#          'message': 0.004,
#          'sunrise': 1554238583,
#          'sunset': 1554280561,
#          'type': 3},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 242, 'gust': 2.24, 'speed': 1.01}}
#
# 605
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 16.22, 'lon': -92.25},
#  'dt': 1554271168,
#  'id': 3516614,
#  'main': {'grnd_level': 907.45,
#           'humidity': 100,
#           'pressure': 1016.13,
#           'sea_level': 1016.13,
#           'temp': 60.61,
#           'temp_max': 60.61,
#           'temp_min': 60.61},
#  'name': 'Socoltenango',
#  'sys': {'country': 'MX',
#          'message': 0.0035,
#          'sunrise': 1554206594,
#          'sunset': 1554250899},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 3.71}}
#
# 606
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 31.89, 'lon': -85.15},
#  'dt': 1554271123,
#  'id': 4060954,
#  'main': {'humidity': 93,
#           'pressure': 1024,
#           'temp': 46.83,
#           'temp_max': 52,
#           'temp_min': 42.8},
#  'name': 'Eufaula',
#  'sys': {'country': 'US',
#          'id': 3439,
#          'message': 0.0055,
#          'sunrise': 1554290795,
#          'sunset': 1554336054,
#          'type': 1},
#  'visibility': 11265,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 328, 'speed': 4.38}}
#
# 607
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 7.57, 'lon': -9.26},
#  'dt': 1554271169,
#  'id': 2414079,
#  'main': {'grnd_level': 953.21,
#           'humidity': 93,
#           'pressure': 1011.01,
#           'sea_level': 1011.01,
#           'temp': 68.98,
#           'temp_max': 68.98,
#           'temp_min': 68.98},
#  'name': 'Yomou',
#  'sys': {'country': 'GN',
#          'message': 0.0037,
#          'sunrise': 1554273246,
#          'sunset': 1554317183},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 299, 'speed': 2.82}}
#
# 608
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 19.3, 'lon': 97.96},
#  'dt': 1554267600,
#  'id': 1152222,
#  'main': {'humidity': 30,
#           'pressure': 1012,
#           'temp': 93.2,
#           'temp_max': 93.2,
#           'temp_min': 93.2},
#  'name': 'Mae Hong Son',
#  'sys': {'country': 'MM',
#          'id': 9246,
#          'message': 0.0035,
#          'sunrise': 1554247245,
#          'sunset': 1554291729,
#          'type': 1},
#  'visibility': 3000,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 190, 'speed': 3.36}}
#
# 609
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 67.86, 'lon': 20.23},
#  'dt': 1554268800,
#  'id': 605155,
#  'main': {'humidity': 85,
#           'pressure': 1009,
#           'temp': 21.2,
#           'temp_max': 21.2,
#           'temp_min': 21.2},
#  'name': 'Kiruna',
#  'sys': {'country': 'SE',
#          'id': 1771,
#          'message': 0.0039,
#          'sunrise': 1554262901,
#          'sunset': 1554313376,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 10.29}}
#
# 610
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.55, 'lon': -58.74},
#  'dt': 1554271089,
#  'id': 3430443,
#  'main': {'humidity': 51,
#           'pressure': 1004,
#           'temp': 51.01,
#           'temp_max': 51.01,
#           'temp_min': 51.01},
#  'name': 'Necochea',
#  'sys': {'country': 'AR',
#          'id': 2018236,
#          'message': 0.0034,
#          'sunrise': 1554286242,
#          'sunset': 1554327933,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 216, 'gust': 3.13, 'speed': 5.01}}
#
# 611
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -3.47, 'lon': 31.9},
#  'dt': 1554271170,
#  'id': 149129,
#  'main': {'grnd_level': 882.73,
#           'humidity': 92,
#           'pressure': 1010.29,
#           'sea_level': 1010.29,
#           'temp': 68.53,
#           'temp_max': 68.53,
#           'temp_min': 68.53},
#  'name': 'Ushirombo',
#  'rain': {'3h': 1.345},
#  'sys': {'country': 'TZ',
#          'message': 0.011,
#          'sunrise': 1554263613,
#          'sunset': 1554307063},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 164, 'speed': 1.7}}

# %%
cities_weather.tail()
# Out:
#              City Country        Date Latitude Longitude Cloudiness Max_Temp  \
# 607         yomou      GN  1554271169     7.57     -9.26         76    68.98
# 608  mae hong son      MM  1554267600     19.3     97.96          0     93.2
# 609        kiruna      SE  1554268800    67.86     20.23         32     21.2
# 610      necochea      AR  1554271089   -38.55    -58.74          0    51.01
# 611     ushirombo      TZ  1554271170    -3.47      31.9         88    68.53
#
#     Humidity Wind_Speed
# 607       93       2.82
# 608       30       3.36
# 609       85      10.29
# 610       51       5.01
# 611       92        1.7

# %%
# Drop rows with any empty cells
cities_weather.dropna(axis=0, how='any', inplace=True)
cities_weather
# Out:
#                    City Country        Date Latitude Longitude Cloudiness  \
# 0                 baker      US  1554268500    46.37   -104.28          1
# 1             marystown      CA  1554270367    47.17    -55.16          0
# 2           barentsburg
# 3               rikitea      PF  1554270464   -23.12   -134.97         44
# 4               ushuaia      AR  1554267600   -54.81    -68.31         40
# 5                matara      PE  1554270626   -13.74     -72.9         36
# 6              tasiilaq      GL  1554267000    65.61    -37.64         92
# 7           port alfred      ZA  1554270350   -33.59     26.89         68
# 8                atuona      PF  1554270501     -9.8   -139.03         68
# 9             jamestown      AU  1554270262   -33.21     138.6          0
# 10             challans      FR  1554270780    46.85     -1.88         75
# 11            hithadhoo      MV  1554270286     -0.6     73.08         76
# 12                 hilo      US  1554270450    19.71   -155.08         75
# 13              mataura      NZ  1554270006   -46.19    168.86          0
# 14               luanda      AO  1554267600    -8.83     13.24         75
# 15            saskylakh      RU  1554270488    71.97    114.09         80
# 16         sentyabrskiy
# 17       cabo san lucas      MX  1554270346    22.89   -109.91          5
# 18           port blair      IN  1554270540    11.67     92.75          0
# 19              vaitupu
# 20            busselton      AU  1554270364   -33.64    115.35          0
# 21             acapulco      MX  1554266940    16.86    -99.88          5
# 22          yellowknife      CA  1554270228    62.45   -114.38          5
# 23               castro      CL  1554267600   -42.48    -73.76         20
# 24                 hofn      IS  1554270563    64.25    -15.21          0
# 25               forbes      AU  1554270513   -33.38    148.01          0
# 26           harrisburg      US  1554270794    40.27    -76.89          1
# 27                pevek      RU  1554270474     69.7    170.27          0
# 28                 ajra      IN  1554267600    16.12     74.21          0
# 29               barrow      AR  1554270468   -38.31    -60.23          0
# ..                  ...     ...         ...      ...       ...        ...
# 582              palasa
# 583               lamar      US  1554270354    38.09   -102.62         90
# 584            bandipur      IN  1554271163    11.67     76.63          0
# 585     haines junction      CA  1554271163    60.75   -137.51         64
# 586           jiayuguan      CN  1554271128    39.77     98.29         44
# 587               young      UY  1554271164    -32.7    -57.63         12
# 588              sorvag
# 589            uyemskiy      RU  1554269400    64.47     40.85         20
# 590  havre-saint-pierre      CA  1554267600    50.23     -63.6         40
# 591                sola      NO  1554271088    58.89      5.65         75
# 592              bacsay      PH  1554267600    15.65    120.33         75
# 593          navahrudak      BY  1554271165    53.59     25.82          0
# 594             shimoda      JP  1554270912     34.7    138.93         40
# 595             ahipara      NZ  1554271069   -35.17    173.16         92
# 596       ponta delgada      PT  1554271160    37.73    -25.67         75
# 597             pitimbu      BR  1554267600    -7.47    -34.81         40
# 598               tuban      ID  1554271166     -6.9    112.07         24
# 599          fort smith      US  1554271161    35.39    -94.42          1
# 600               lolua
# 601              samusu
# 602            mabaruma      GY  1554271167      8.2    -59.78         12
# 603             waipawa      NZ  1554270736   -39.94    176.59         92
# 604       murray bridge      AU  1554270970   -35.12    139.28         68
# 605        socoltenango      MX  1554271168    16.22    -92.25          0
# 606             eufaula      US  1554271123    31.89    -85.15          1
# 607               yomou      GN  1554271169     7.57     -9.26         76
# 608        mae hong son      MM  1554267600     19.3     97.96          0
# 609              kiruna      SE  1554268800    67.86     20.23         32
# 610            necochea      AR  1554271089   -38.55    -58.74          0
# 611           ushirombo      TZ  1554271170    -3.47      31.9         88
#
#     Max_Temp Humidity Wind_Speed
# 0       28.4       74       3.36
# 1      28.99      100      11.54
# 2
# 3      75.37      100      16.91
# 4       39.2       93        4.7
# 5      38.29       97       2.04
# 6         32       93      46.08
# 7      62.01       92      21.39
# 8      81.85      100      12.77
# 9      77.08       40       5.95
# 10        43       93       5.82
# 11     84.73      100       9.75
# 12        75       78      12.75
# 13        57       67          3
# 14      75.2       94       3.36
# 15     30.64      100       4.61
# 16
# 17      73.4       40      11.41
# 18     84.82      100       5.95
# 19
# 20     80.01       31        5.5
# 21      78.8       83        4.7
# 22       1.4       70       8.05
# 23      44.6      100       5.82
# 24     26.68      100        1.7
# 25        81       30        4.5
# 26      39.2       80        4.7
# 27     23.08       66        6.4
# 28      91.4       15       6.93
# 29     52.51       91       5.06
# ..       ...      ...        ...
# 582
# 583     46.4       65      13.87
# 584    88.96       34       2.04
# 585    27.76       93       2.59
# 586    48.91       70       4.94
# 587    64.48       94      11.77
# 588
# 589     35.6       64       6.71
# 590       23       85       9.17
# 591     48.2       49      17.22
# 592     91.4       49       2.24
# 593    36.04       58      11.77
# 594    60.01       18      10.29
# 595    64.21       98       9.75
# 596     55.4       76      10.29
# 597       77       94        4.7
# 598    86.08       85       4.16
# 599     53.6       87       3.71
# 600
# 601
# 602    73.84       93       5.17
# 603       54       70       1.99
# 604    75.99       40       1.01
# 605    60.61      100       3.71
# 606       52       93       4.38
# 607    68.98       93       2.82
# 608     93.2       30       3.36
# 609     21.2       85      10.29
# 610    51.01       51       5.01
# 611    68.53       92        1.7
#
# [612 rows x 9 columns]

# %%
cities_weather.count()
# Out:
# City          612
# Country       612
# Date          612
# Latitude      612
# Longitude     612
# Cloudiness    612
# Max_Temp      612
# Humidity      612
# Wind_Speed    612
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_weather.head()
# Out:
#           City Country        Date Latitude Longitude Cloudiness Max_Temp  \
# 0        baker      US  1554268500    46.37   -104.28          1     28.4
# 1    marystown      CA  1554270367    47.17    -55.16          0    28.99
# 2  barentsburg
# 3      rikitea      PF  1554270464   -23.12   -134.97         44    75.37
# 4      ushuaia      AR  1554267600   -54.81    -68.31         40     39.2
#
#   Humidity Wind_Speed
# 0       74       3.36
# 1      100      11.54
# 2
# 3      100      16.91
# 4       93        4.7

# %%
cities_weather.to_csv('cities_weather.csv',index=False)

# %%
cities_weather.dtypes
# Out:
# City          object
# Country       object
# Date          object
# Latitude      object
# Longitude     object
# Cloudiness    object
# Max_Temp      object
# Humidity      object
# Wind_Speed    object
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Max_Temp"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Max Temperature (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature (F)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_MTemp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Humidity"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Humidity (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Humidity (%)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Cloudiness"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Cloudiness (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Cloudiness (%)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Wind_Speed"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Wind Speed (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Wind Speed (mph)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Wind_Speed')
