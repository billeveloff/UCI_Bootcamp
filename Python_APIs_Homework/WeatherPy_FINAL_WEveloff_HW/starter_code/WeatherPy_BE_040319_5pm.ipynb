# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
# import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
from pprint import pprint

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %%
print(lat_lngs)
# Out:
# <zip object at 0x000002089F353208>

# %%
len(lats)
# Out:
# 1500

# %%
len(lngs)
# Out:
# 1500

# %%
coordinates_df = pd.DataFrame({'Latitude': lats, 'Longitude': lngs})
coordinates_df.tail()
# Out:
#        Latitude   Longitude
# 1495  88.031441  -85.966301
# 1496  61.714016   39.631893
# 1497  74.675854  138.416850
# 1498 -77.430160  -42.955396
# 1499  48.889585 -165.252031

# %%
cities_df = pd.DataFrame({'City': cities})
cities_df.tail()
# Out:
#            City
# 621  patacamaya
# 622      xifeng
# 623    saleaula
# 624   kathmandu
# 625      konevo

# %%
cities_weather = cities_df.copy()
cities_weather.head()
# Out:
#            City
# 0          hilo
# 1        miyako
# 2      kushtagi
# 3    butaritari
# 4  punta arenas

# %%
#setting up additional columns in dataframe
cities_weather ['Country'] = ""
cities_weather ['Date'] = ""
cities_weather ['Latitude'] = ""
cities_weather ['Longitude'] = ""
cities_weather ['Cloudiness'] = ""
cities_weather ['Max_Temp'] = ""
cities_weather ['Humidity'] = ""
cities_weather ['Wind_Speed'] = ""

cities_weather.head()
# Out:
#            City Country Date Latitude Longitude Cloudiness Max_Temp Humidity  \
# 0          hilo
# 1        miyako
# 2      kushtagi
# 3    butaritari
# 4  punta arenas
#
#   Wind_Speed
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# import openweathermapy.core as owm
# Base url and define units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Query url
query_url = f"{url}appid={api_key}&units={units}&q="

# use iterrows to iterate through pandas dataframe
for index, row in cities_weather.iterrows():
    print(index)

    cityrow = row['City']
    
    try:
        response = requests.get(query_url + cityrow).json()
        pprint(response)

        results = response

        cities_weather.loc[index, 'Country'] = results['sys']['country']
        cities_weather.loc[index, 'Date'] = results['dt']
        cities_weather.loc[index, 'Latitude'] = results['coord']['lat']
        cities_weather.loc[index, 'Longitude'] = results['coord']['lon']
        cities_weather.loc[index, 'Cloudiness'] = results['clouds']['all']
        cities_weather.loc[index, 'Max_Temp'] = results['main']['temp_max']
        cities_weather.loc[index, 'Humidity'] = results['main']['humidity']
        cities_weather.loc[index, 'Wind_Speed'] = results['wind']['speed']
        print()
        
    except (KeyError, IndexError):
        print("Data not found... skipping.")
        print("------------")
# Out:
# 0
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1554341122,
#  'id': 5855927,
#  'main': {'humidity': 61,
#           'pressure': 1020,
#           'temp': 73.44,
#           'temp_max': 80.6,
#           'temp_min': 68},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'message': 0.0048,
#          'sunrise': 1554307928,
#          'sunset': 1554352480,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 14.99}}
#
# 1
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 33.63, 'lon': 130.94},
#  'dt': 1554341026,
#  'id': 1848087,
#  'main': {'humidity': 50,
#           'pressure': 1020,
#           'temp': 57.09,
#           'temp_max': 59,
#           'temp_min': 55.4},
#  'name': 'Miyako',
#  'sys': {'country': 'JP',
#          'id': 7995,
#          'message': 0.0034,
#          'sunrise': 1554325242,
#          'sunset': 1554370669,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 6.93}}
#
# 2
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 15.76, 'lon': 76.19},
#  'dt': 1554341429,
#  'id': 1265446,
#  'main': {'grnd_level': 949.91,
#           'humidity': 62,
#           'pressure': 1013.4,
#           'sea_level': 1013.4,
#           'temp': 77.13,
#           'temp_max': 77.13,
#           'temp_min': 77.13},
#  'name': 'Kushtagi',
#  'sys': {'country': 'IN',
#          'message': 0.0036,
#          'sunrise': 1554338911,
#          'sunset': 1554383275},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 224.001, 'speed': 6.2}}
#
# 3
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1554341255,
#  'id': 2110227,
#  'main': {'grnd_level': 1011.81,
#           'humidity': 100,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 78.26,
#           'temp_max': 78.26,
#           'temp_min': 78.26},
#  'name': 'Butaritari',
#  'rain': {'3h': 2.6825},
#  'sys': {'country': 'KI',
#          'message': 0.0031,
#          'sunrise': 1554316043,
#          'sunset': 1554359784},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 25.5015, 'speed': 2.48}}
#
# 4
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1554340948,
#  'id': 3874787,
#  'main': {'humidity': 65,
#           'pressure': 991,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.0047,
#          'sunrise': 1554289772,
#          'sunset': 1554330243,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 21.92}}
#
# 5
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1554341253,
#  'id': 2175403,
#  'main': {'grnd_level': 998.53,
#           'humidity': 50,
#           'pressure': 1021.16,
#           'sea_level': 1021.16,
#           'temp': 78.53,
#           'temp_max': 78.53,
#           'temp_min': 78.53},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0036,
#          'sunrise': 1554322357,
#          'sunset': 1554364853},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 124.001, 'speed': 14.67}}
#
# 6
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 6.65, 'lon': -75.46},
#  'dt': 1554341170,
#  'id': 3668451,
#  'main': {'humidity': 93,
#           'pressure': 1026,
#           'temp': 59.76,
#           'temp_max': 62.6,
#           'temp_min': 57},
#  'name': 'Santa Rosa de Osos',
#  'sys': {'country': 'CO',
#          'id': 8619,
#          'message': 0.0075,
#          'sunrise': 1554289149,
#          'sunset': 1554333049,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 4.7}}
#
# 7
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -3.43, 'lon': -60.46},
#  'dt': 1554339600,
#  'id': 3663524,
#  'main': {'humidity': 94,
#           'pressure': 1012,
#           'temp': 77.9,
#           'temp_max': 78.8,
#           'temp_min': 77},
#  'name': 'Manaquiri',
#  'sys': {'country': 'BR',
#          'id': 8412,
#          'message': 0.0034,
#          'sunrise': 1554285775,
#          'sunset': 1554329224,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11n',
#               'id': 211,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 180, 'speed': 4.7}}
#
# 8
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -8.93, 'lon': 125.41},
#  'dt': 1554341219,
#  'id': 1651810,
#  'main': {'grnd_level': 936.05,
#           'humidity': 73,
#           'pressure': 1011.8,
#           'sea_level': 1011.8,
#           'temp': 74.03,
#           'temp_max': 74.03,
#           'temp_min': 74.03},
#  'name': 'Airai',
#  'sys': {'country': 'TL',
#          'message': 0.003,
#          'sunrise': 1554327686,
#          'sunset': 1554370879},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 97.0015, 'speed': 1.14}}
#
# 9
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1554339600,
#  'id': 3378644,
#  'main': {'humidity': 83,
#           'pressure': 1013,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'id': 8776,
#          'message': 0.0037,
#          'sunrise': 1554284995,
#          'sunset': 1554328901,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 13.87}}
#
# 10
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1554340984,
#  'id': 4030556,
#  'main': {'grnd_level': 1018.45,
#           'humidity': 100,
#           'pressure': 1018.56,
#           'sea_level': 1018.56,
#           'temp': 75.29,
#           'temp_max': 75.29,
#           'temp_min': 75.29},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0031,
#          'sunrise': 1554304110,
#          'sunset': 1554346647},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109.501, 'speed': 19.04}}
#
# 11
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 69.7, 'lon': 170.27},
#  'dt': 1554341147,
#  'id': 2122090,
#  'main': {'grnd_level': 1012.69,
#           'humidity': 79,
#           'pressure': 1020.12,
#           'sea_level': 1020.12,
#           'temp': 25.7,
#           'temp_max': 25.7,
#           'temp_min': 25.7},
#  'name': 'Pevek',
#  'sys': {'country': 'RU',
#          'message': 0.0031,
#          'sunrise': 1554312762,
#          'sunset': 1554364275},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 356.001, 'speed': 2.59}}
#
# 12
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 33.93, 'lon': 134.5},
#  'dt': 1554339850,
#  'id': 1865309,
#  'main': {'humidity': 37,
#           'pressure': 1019,
#           'temp': 55.24,
#           'temp_max': 55.4,
#           'temp_min': 55},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 8027,
#          'message': 0.0038,
#          'sunrise': 1554324377,
#          'sunset': 1554369825,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 3.36}}
#
# 13
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1554341212,
#  'id': 344979,
#  'main': {'grnd_level': 767.57,
#           'humidity': 92,
#           'pressure': 1013.16,
#           'sea_level': 1013.16,
#           'temp': 51.35,
#           'temp_max': 51.35,
#           'temp_min': 51.35},
#  'name': 'Lebu',
#  'rain': {'3h': 2.2025},
#  'sys': {'country': 'ET',
#          'message': 0.0043,
#          'sunrise': 1554348068,
#          'sunset': 1554392094},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 334.501, 'speed': 3.27}}
#
# 14
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 6.12, 'lon': 81.12},
#  'dt': 1554340200,
#  'id': 1244926,
#  'main': {'humidity': 100,
#           'pressure': 1013,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Hambantota',
#  'sys': {'country': 'LK',
#          'id': 9124,
#          'message': 0.0046,
#          'sunrise': 1554337966,
#          'sunset': 1554381853,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 1.12}}
#
# 15
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -20.41, 'lon': 57.7},
#  'dt': 1554341043,
#  'id': 934322,
#  'main': {'humidity': 94,
#           'pressure': 1013,
#           'temp': 75.67,
#           'temp_max': 75.99,
#           'temp_min': 75.2},
#  'name': 'Mahebourg',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'message': 0.0043,
#          'sunrise': 1554344211,
#          'sunset': 1554386848,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1.12}}
#
# 16
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 70.62, 'lon': 147.9},
#  'dt': 1554341110,
#  'id': 2126123,
#  'main': {'grnd_level': 1015.81,
#           'humidity': 90,
#           'pressure': 1017.92,
#           'sea_level': 1017.92,
#           'temp': 12.83,
#           'temp_max': 12.83,
#           'temp_min': 12.83},
#  'name': 'Chokurdakh',
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1554317894,
#          'sunset': 1554369878},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 141.501, 'speed': 4.16}}
#
# 17
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 60.72, 'lon': -46.03},
#  'dt': 1554341241,
#  'id': 3420846,
#  'main': {'grnd_level': 1020.69,
#           'humidity': 100,
#           'pressure': 1023.56,
#           'sea_level': 1023.56,
#           'temp': 32.18,
#           'temp_max': 32.18,
#           'temp_min': 32.18},
#  'name': 'Qaqortoq',
#  'sys': {'country': 'GL',
#          'message': 0.0042,
#          'sunrise': 1554279757,
#          'sunset': 1554328318},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 295.501, 'speed': 13.22}}
#
# 18
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 44.6, 'lon': 8.98},
#  'dt': 1554341420,
#  'id': 3176217,
#  'main': {'humidity': 87,
#           'pressure': 999,
#           'temp': 54.41,
#           'temp_max': 57.2,
#           'temp_min': 51.01},
#  'name': 'Bastia',
#  'sys': {'country': 'IT',
#          'id': 6737,
#          'message': 0.0045,
#          'sunrise': 1554354011,
#          'sunset': 1554400428,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 130, 'speed': 34.45}}
#
# 19
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 68.75, 'lon': 161.3},
#  'dt': 1554341247,
#  'id': 2126199,
#  'main': {'grnd_level': 1010.29,
#           'humidity': 75,
#           'pressure': 1018.4,
#           'sea_level': 1018.4,
#           'temp': 29.93,
#           'temp_max': 29.93,
#           'temp_min': 29.93},
#  'name': 'Cherskiy',
#  'sys': {'country': 'RU',
#          'message': 0.0038,
#          'sunrise': 1554315113,
#          'sunset': 1554366228},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 102.501, 'speed': 2.26}}
#
# 20
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1554339600,
#  'id': 3833367,
#  'main': {'humidity': 69,
#           'pressure': 983,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0044,
#          'sunrise': 1554289240,
#          'sunset': 1554329528,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 200, 'gust': 18.5, 'speed': 27.51}}
#
# 21
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1554341107,
#  'id': 2075265,
#  'main': {'humidity': 46,
#           'pressure': 1008,
#           'temp': 63.54,
#           'temp_max': 68,
#           'temp_min': 60.01},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'message': 0.0031,
#          'sunrise': 1554330731,
#          'sunset': 1554372661,
#          'type': 3},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 231.001, 'speed': 19.26}}
#
# 22
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 23
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 65.58, 'lon': -170.99},
#  'dt': 1554341161,
#  'id': 4031637,
#  'main': {'grnd_level': 1014.93,
#           'humidity': 100,
#           'pressure': 1019.16,
#           'sea_level': 1019.16,
#           'temp': 24.98,
#           'temp_max': 24.98,
#           'temp_min': 24.98},
#  'name': 'Lavrentiya',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1554395220,
#          'sunset': 1554445587},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 37.5015, 'speed': 16.58}}
#
# 24
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 63.75, 'lon': -68.52},
#  'dt': 1554340923,
#  'id': 5983720,
#  'main': {'humidity': 70,
#           'pressure': 1011,
#           'temp': -2.1,
#           'temp_max': -2.01,
#           'temp_min': -2.21},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 797,
#          'message': 0.0044,
#          'sunrise': 1554284782,
#          'sunset': 1554334086,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 4.7}}
#
# 25
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 47.44, 'lon': -79.64},
#  'dt': 1554341280,
#  'id': 5968992,
#  'main': {'humidity': 62,
#           'pressure': 1018,
#           'temp': 24.8,
#           'temp_max': 24.8,
#           'temp_min': 24.8},
#  'name': 'Haileybury',
#  'sys': {'country': 'CA',
#          'id': 981,
#          'message': 0.0032,
#          'sunrise': 1554288816,
#          'sunset': 1554335388,
#          'type': 1},
#  'visibility': 9656,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 290, 'gust': 14.9, 'speed': 19.46}}
#
# 26
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -2.67, 'lon': 141.3},
#  'dt': 1554341313,
#  'id': 2084442,
#  'main': {'grnd_level': 1010.45,
#           'humidity': 97,
#           'pressure': 1010.6,
#           'sea_level': 1010.6,
#           'temp': 83.75,
#           'temp_max': 83.75,
#           'temp_min': 83.75},
#  'name': 'Vanimo',
#  'rain': {'3h': 2.5},
#  'sys': {'country': 'PG',
#          'message': 0.0051,
#          'sunrise': 1554323730,
#          'sunset': 1554367209},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 286.001, 'speed': 15.01}}
#
# 27
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 11, 'lon': 122.67},
#  'dt': 1554341138,
#  'id': 1714733,
#  'main': {'grnd_level': 993.81,
#           'humidity': 71,
#           'pressure': 1013.8,
#           'sea_level': 1013.8,
#           'temp': 80.06,
#           'temp_max': 80.06,
#           'temp_min': 80.06},
#  'name': 'Dingle',
#  'sys': {'country': 'PH',
#          'message': 0.0035,
#          'sunrise': 1554327881,
#          'sunset': 1554371999},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 41.5015, 'speed': 10.76}}
#
# 28
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 4.94, 'lon': -52.33},
#  'dt': 1554339600,
#  'id': 3382160,
#  'main': {'humidity': 74,
#           'pressure': 1013,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Cayenne',
#  'sys': {'country': 'GF',
#          'id': 8669,
#          'message': 0.0036,
#          'sunrise': 1554283639,
#          'sunset': 1554327459,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 6.93}}
#
# 29
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 4.27, 'lon': -54.38},
#  'dt': 1554341435,
#  'id': 3381538,
#  'main': {'grnd_level': 997.67,
#           'humidity': 72,
#           'pressure': 1013.48,
#           'sea_level': 1013.48,
#           'temp': 79.02,
#           'temp_max': 79.02,
#           'temp_min': 79.02},
#  'name': 'Grand-Santi',
#  'sys': {'country': 'GF',
#          'message': 0.0033,
#          'sunrise': 1554284146,
#          'sunset': 1554327936},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 38.5015, 'speed': 3.96}}
#
# 30
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1554340991,
#  'id': 3369157,
#  'main': {'humidity': 87,
#           'pressure': 1012,
#           'temp': 56.59,
#           'temp_max': 59,
#           'temp_min': 55},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'message': 0.0036,
#          'sunrise': 1554354015,
#          'sunset': 1554395894,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 5.82}}
#
# 31
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1554340924,
#  'id': 5106834,
#  'main': {'humidity': 35,
#           'pressure': 1021,
#           'temp': 39.42,
#           'temp_max': 43,
#           'temp_min': 35.01},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 3273,
#          'message': 0.0067,
#          'sunrise': 1554287643,
#          'sunset': 1554333734,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'gust': 13.9, 'speed': 19.46}}
#
# 32
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.78, 'lon': 147.06},
#  'dt': 1554341176,
#  'id': 2155415,
#  'main': {'humidity': 44,
#           'pressure': 1036,
#           'temp': 58.62,
#           'temp_max': 61,
#           'temp_min': 57},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0034,
#          'sunrise': 1554323425,
#          'sunset': 1554364750,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 6.93}}
#
# 33
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 34
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1554340807,
#  'id': 6201424,
#  'main': {'humidity': 90,
#           'pressure': 1024,
#           'temp': 52,
#           'temp_max': 52,
#           'temp_min': 52},
#  'name': 'Mataura',
#  'rain': {'3h': 2.905},
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0037,
#          'sunrise': 1554318325,
#          'sunset': 1554359388,
#          'type': 3},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 206, 'gust': 7.15, 'speed': 8.99}}
#
# 35
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 13.72, 'lon': 123.58},
#  'dt': 1554341201,
#  'id': 1691355,
#  'main': {'grnd_level': 1005.09,
#           'humidity': 85,
#           'pressure': 1014.92,
#           'sea_level': 1014.92,
#           'temp': 80.33,
#           'temp_max': 80.33,
#           'temp_min': 80.33},
#  'name': 'Sabang',
#  'sys': {'country': 'PH',
#          'message': 0.0033,
#          'sunrise': 1554327595,
#          'sunset': 1554371848},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 98.5015, 'speed': 7.29}}
#
# 36
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -7.37, 'lon': 108.54},
#  'dt': 1554341187,
#  'id': 1650233,
#  'main': {'grnd_level': 975.09,
#           'humidity': 92,
#           'pressure': 1012.4,
#           'sea_level': 1012.4,
#           'temp': 72.23,
#           'temp_max': 72.23,
#           'temp_min': 72.23},
#  'name': 'Banjar',
#  'sys': {'country': 'ID',
#          'message': 0.0029,
#          'sunrise': 1554331699,
#          'sunset': 1554374962},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 232.001, 'speed': 3.49}}
#
# 37
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1554341136,
#  'id': 546105,
#  'main': {'humidity': 46,
#           'pressure': 1024,
#           'temp': 29.95,
#           'temp_max': 34,
#           'temp_min': 26.01},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'message': 0.0032,
#          'sunrise': 1554347685,
#          'sunset': 1554396288,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 6.71}}
#
# 38
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 21.94, 'lon': -78.43},
#  'dt': 1554339000,
#  'id': 3543498,
#  'main': {'humidity': 73,
#           'pressure': 1021,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Primero de Enero',
#  'sys': {'country': 'CU',
#          'id': 7232,
#          'message': 0.0033,
#          'sunrise': 1554289483,
#          'sunset': 1554334140,
#          'type': 1},
#  'visibility': 9000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 12.75}}
#
# 39
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -28.65, 'lon': 153.62},
#  'dt': 1554341053,
#  'id': 2172880,
#  'main': {'humidity': 57,
#           'pressure': 1025,
#           'temp': 76.08,
#           'temp_max': 78.01,
#           'temp_min': 75.2},
#  'name': 'Byron Bay',
#  'sys': {'country': 'AU',
#          'id': 9486,
#          'message': 0.004,
#          'sunrise': 1554321399,
#          'sunset': 1554363628,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 14.99}}
#
# 40
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 41
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 26.45, 'lon': -81.95},
#  'dt': 1554341168,
#  'id': 4155996,
#  'main': {'humidity': 64,
#           'pressure': 1023,
#           'temp': 72.43,
#           'temp_max': 73.4,
#           'temp_min': 71.01},
#  'name': 'Fort Myers Beach',
#  'sys': {'country': 'US',
#          'id': 4122,
#          'message': 0.0049,
#          'sunrise': 1554290199,
#          'sunset': 1554335114,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 12.75}}
#
# 42
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 35.85, 'lon': 71.79},
#  'dt': 1554341438,
#  'id': 1181065,
#  'main': {'grnd_level': 656.71,
#           'humidity': 91,
#           'pressure': 1020.96,
#           'sea_level': 1020.96,
#           'temp': 25.2,
#           'temp_max': 25.2,
#           'temp_min': 25.2},
#  'name': 'Chitral',
#  'sys': {'country': 'PK',
#          'message': 0.0033,
#          'sunrise': 1554339342,
#          'sunset': 1554384955},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 52.0015, 'speed': 1.05}}
#
# 43
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1554341216,
#  'id': 2022572,
#  'main': {'grnd_level': 1001.81,
#           'humidity': 88,
#           'pressure': 1006.64,
#           'sea_level': 1006.64,
#           'temp': 17.06,
#           'temp_max': 17.06,
#           'temp_min': 17.06},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU',
#          'message': 0.0032,
#          'sunrise': 1554328390,
#          'sunset': 1554381183},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 325.501, 'speed': 9.98}}
#
# 44
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 49.72, 'lon': -86.95},
#  'dt': 1554339600,
#  'id': 5960603,
#  'main': {'humidity': 48,
#           'pressure': 1021,
#           'temp': 21.2,
#           'temp_max': 21.2,
#           'temp_min': 21.2},
#  'name': 'Geraldton',
#  'sys': {'country': 'CA',
#          'id': 810,
#          'message': 0.0042,
#          'sunrise': 1554290438,
#          'sunset': 1554337275,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'gust': 8.2, 'speed': 8.05}}
#
# 45
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 59.24, 'lon': 163.07},
#  'dt': 1554341439,
#  'id': 2122389,
#  'main': {'grnd_level': 986.07,
#           'humidity': 95,
#           'pressure': 998.28,
#           'sea_level': 998.28,
#           'temp': 32.67,
#           'temp_max': 32.67,
#           'temp_min': 32.67},
#  'name': 'Ossora',
#  'sys': {'country': 'RU',
#          'message': 0.0036,
#          'sunrise': 1554316050,
#          'sunset': 1554364441},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 49.5015, 'speed': 21.63}}
#
# 46
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1554336000,
#  'id': 6165406,
#  'main': {'humidity': 37,
#           'pressure': 1022,
#           'temp': 19.4,
#           'temp_max': 19.4,
#           'temp_min': 19.4},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'message': 0.0042,
#          'sunrise': 1554292633,
#          'sunset': 1554340315,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 287.001, 'speed': 3.49}}
#
# 47
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 69.44, 'lon': -133.03},
#  'dt': 1554336000,
#  'id': 6170031,
#  'main': {'humidity': 70,
#           'pressure': 1027,
#           'temp': 1.4,
#           'temp_max': 1.4,
#           'temp_min': 1.4},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 942,
#          'message': 0.0049,
#          'sunrise': 1554299255,
#          'sunset': 1554350571,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 310, 'speed': 10.29}}
#
# 48
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 50.68, 'lon': 156.12},
#  'dt': 1554341266,
#  'id': 2121385,
#  'main': {'grnd_level': 967.81,
#           'humidity': 90,
#           'pressure': 980.72,
#           'sea_level': 980.72,
#           'temp': 35.06,
#           'temp_max': 35.06,
#           'temp_min': 35.06},
#  'name': 'Severo-Kurilsk',
#  'sys': {'country': 'RU',
#          'message': 0.0045,
#          'sunrise': 1554318399,
#          'sunset': 1554365428},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 322.001, 'speed': 5.61}}
#
# 49
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 6.41, 'lon': -58.62},
#  'dt': 1554341440,
#  'id': 3379507,
#  'main': {'grnd_level': 1009.43,
#           'humidity': 82,
#           'pressure': 1014.56,
#           'sea_level': 1014.56,
#           'temp': 76.5,
#           'temp_max': 76.5,
#           'temp_min': 76.5},
#  'name': 'Bartica',
#  'sys': {'country': 'GY',
#          'message': 0.0036,
#          'sunrise': 1554285115,
#          'sunset': 1554329002},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 46.5015, 'speed': 4.07}}
#
# 50
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1554341244,
#  'id': 3833859,
#  'main': {'grnd_level': 992.45,
#           'humidity': 41,
#           'pressure': 1004.12,
#           'sea_level': 1004.12,
#           'temp': 65.03,
#           'temp_max': 65.03,
#           'temp_min': 65.03},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.0044,
#          'sunrise': 1554286592,
#          'sunset': 1554328298},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 351.001, 'speed': 13}}
#
# 51
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 52
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 41.2, 'lon': 36.72},
#  'dt': 1554339000,
#  'id': 749704,
#  'main': {'humidity': 75,
#           'pressure': 1019,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Carsamba',
#  'sys': {'country': 'TR',
#          'id': 7017,
#          'message': 0.0108,
#          'sunrise': 1554347526,
#          'sunset': 1554393601,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 75.5015, 'speed': 7.43}}
#
# 53
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.1, 'lon': 26.19},
#  'dt': 1554341189,
#  'id': 588365,
#  'main': {'grnd_level': 1015.41,
#           'humidity': 77,
#           'pressure': 1023.44,
#           'sea_level': 1023.44,
#           'temp': 32.99,
#           'temp_max': 32.99,
#           'temp_min': 32.99},
#  'name': 'Vao',
#  'sys': {'country': 'EE',
#          'message': 0.0031,
#          'sunrise': 1554348849,
#          'sunset': 1554397332},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 175.501, 'speed': 8.52}}
#
# 54
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -28.95, 'lon': 153.24},
#  'dt': 1554341053,
#  'id': 2160063,
#  'main': {'humidity': 64,
#           'pressure': 1026,
#           'temp': 76.32,
#           'temp_max': 78.01,
#           'temp_min': 75.2},
#  'name': 'Codrington',
#  'sys': {'country': 'AU',
#          'id': 9537,
#          'message': 0.004,
#          'sunrise': 1554321498,
#          'sunset': 1554363711,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 9.17}}
#
# 55
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 42.78, 'lon': 124.11},
#  'dt': 1554341441,
#  'id': 2038139,
#  'main': {'grnd_level': 980.47,
#           'humidity': 55,
#           'pressure': 1001.28,
#           'sea_level': 1001.28,
#           'temp': 57.06,
#           'temp_max': 57.06,
#           'temp_min': 57.06},
#  'name': 'Changtu',
#  'sys': {'country': 'CN',
#          'message': 0.0034,
#          'sunrise': 1554326504,
#          'sunset': 1554372685},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 244.001, 'speed': 15.93}}
#
# 56
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 55.02, 'lon': 73.58},
#  'dt': 1554339600,
#  'id': 1496153,
#  'main': {'humidity': 97,
#           'pressure': 1018,
#           'temp': 32,
#           'temp_max': 32,
#           'temp_min': 32},
#  'name': 'Rostovka',
#  'sys': {'country': 'RU',
#          'id': 8960,
#          'message': 0.0033,
#          'sunrise': 1554337865,
#          'sunset': 1554385573,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 60, 'speed': 13.42}}
#
# 57
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1554341214,
#  'id': 2069194,
#  'main': {'grnd_level': 967.97,
#           'humidity': 41,
#           'pressure': 1025.6,
#           'sea_level': 1025.6,
#           'temp': 72.59,
#           'temp_max': 72.59,
#           'temp_min': 72.59},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0034,
#          'sunrise': 1554325135,
#          'sunset': 1554367100},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 65.5015, 'speed': 7.74}}
#
# 58
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 77.48, 'lon': -69.36},
#  'dt': 1554341247,
#  'id': 3831208,
#  'main': {'grnd_level': 956.45,
#           'humidity': 82,
#           'pressure': 988.64,
#           'sea_level': 988.64,
#           'temp': 10.22,
#           'temp_max': 10.22,
#           'temp_min': 10.22},
#  'name': 'Qaanaaq',
#  'sys': {'country': 'GL',
#          'message': 0.0035,
#          'sunrise': 1554281104,
#          'sunset': 1554338167},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109.501, 'speed': 6.62}}
#
# 59
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 59.36, 'lon': 143.24},
#  'dt': 1554341442,
#  'id': 2122605,
#  'main': {'grnd_level': 1000.47,
#           'humidity': 60,
#           'pressure': 1006.88,
#           'sea_level': 1006.88,
#           'temp': 40.23,
#           'temp_max': 40.23,
#           'temp_min': 40.23},
#  'name': 'Okhotsk',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1554320788,
#          'sunset': 1554369221},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21.0015, 'speed': 3.96}}
#
# 60
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1554339600,
#  'id': 3471451,
#  'main': {'humidity': 88,
#           'pressure': 1012,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'id': 8343,
#          'message': 0.004,
#          'sunrise': 1554281793,
#          'sunset': 1554324357,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 4.7}}
#
# 61
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1554341116,
#  'id': 4020109,
#  'main': {'grnd_level': 1010.93,
#           'humidity': 100,
#           'pressure': 1010.96,
#           'sea_level': 1010.96,
#           'temp': 81.86,
#           'temp_max': 81.86,
#           'temp_min': 81.86},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0037,
#          'sunrise': 1554304772,
#          'sunset': 1554347933},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 89.0015, 'speed': 14}}
#
# 62
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1554341224,
#  'id': 4407665,
#  'main': {'humidity': 71,
#           'pressure': 1018,
#           'temp': 54.66,
#           'temp_max': 55.99,
#           'temp_min': 53.01},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 5924,
#          'message': 0.0096,
#          'sunrise': 1554292798,
#          'sunset': 1554338663,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 9.17}}
#
# 63
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -37.83, 'lon': 140.78},
#  'dt': 1554339600,
#  'id': 2156643,
#  'main': {'humidity': 59,
#           'pressure': 1028,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Mount Gambier',
#  'sys': {'country': 'AU',
#          'id': 9560,
#          'message': 0.0039,
#          'sunrise': 1554324757,
#          'sunset': 1554366431,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 11.41}}
#
# 64
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -0.39, 'lon': -78.55},
#  'dt': 1554340642,
#  'id': 3652462,
#  'main': {'humidity': 87,
#           'pressure': 1028,
#           'temp': 50.92,
#           'temp_max': 57.2,
#           'temp_min': 48},
#  'name': 'San Cristobal',
#  'sys': {'country': 'EC',
#          'id': 8555,
#          'message': 0.0054,
#          'sunrise': 1554290049,
#          'sunset': 1554333632,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'},
#              {'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 20, 'speed': 3.36}}
#
# 65
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 66
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 30.3, 'lon': -99.24},
#  'dt': 1554341278,
#  'id': 4696310,
#  'main': {'humidity': 93,
#           'pressure': 1015,
#           'temp': 62.58,
#           'temp_max': 64,
#           'temp_min': 61},
#  'name': 'Harper',
#  'sys': {'country': 'US',
#          'id': 5990,
#          'message': 0.005,
#          'sunrise': 1554294226,
#          'sunset': 1554339384,
#          'type': 1},
#  'visibility': 8047,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 150, 'speed': 8.05}}
#
# 67
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -46.13, 'lon': 167.69},
#  'dt': 1554340807,
#  'id': 2180815,
#  'main': {'humidity': 90,
#           'pressure': 1024,
#           'temp': 52,
#           'temp_max': 52,
#           'temp_min': 52},
#  'name': 'Tuatapere',
#  'rain': {'3h': 6.115},
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0035,
#          'sunrise': 1554318604,
#          'sunset': 1554359671,
#          'type': 3},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 206, 'gust': 7.15, 'speed': 8.99}}
#
# 68
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 69
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -3.71, 'lon': -38.6},
#  'dt': 1554340687,
#  'id': 6320062,
#  'main': {'humidity': 83,
#           'pressure': 1012,
#           'temp': 80.82,
#           'temp_max': 81,
#           'temp_min': 80.6},
#  'name': 'Vila Velha',
#  'sys': {'country': 'BR',
#          'id': 8363,
#          'message': 0.0065,
#          'sunrise': 1554280536,
#          'sunset': 1554323973,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 4.7}}
#
# 70
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1554340523,
#  'id': 1015776,
#  'main': {'humidity': 87,
#           'pressure': 1010,
#           'temp': 60.24,
#           'temp_max': 61,
#           'temp_min': 59},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'message': 0.0038,
#          'sunrise': 1554353645,
#          'sunset': 1554395487,
#          'type': 1},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 8.05}}
#
# 71
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 42.18, 'lon': 127.48},
#  'dt': 1554341445,
#  'id': 2034691,
#  'main': {'grnd_level': 912.31,
#           'humidity': 30,
#           'pressure': 1001.84,
#           'sea_level': 1001.84,
#           'temp': 53.55,
#           'temp_max': 53.55,
#           'temp_min': 53.55},
#  'name': 'Songjianghe',
#  'sys': {'country': 'CN',
#          'message': 0.0033,
#          'sunrise': 1554325724,
#          'sunset': 1554371847},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 236.001, 'speed': 14.7}}
#
# 72
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -41.87, 'lon': -73.83},
#  'dt': 1554339600,
#  'id': 3899695,
#  'main': {'humidity': 100,
#           'pressure': 1006,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Ancud',
#  'sys': {'country': 'CL',
#          'id': 8512,
#          'message': 0.0036,
#          'sunrise': 1554289979,
#          'sunset': 1554331437,
#          'type': 1},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 6.93}}
#
# 73
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1554341116,
#  'id': 2163355,
#  'main': {'humidity': 44,
#           'pressure': 1036,
#           'temp': 58.62,
#           'temp_max': 61,
#           'temp_min': 57},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0057,
#          'sunrise': 1554323364,
#          'sunset': 1554364682,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 6.93}}
#
# 74
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 18.22, 'lon': -63.06},
#  'dt': 1554340610,
#  'id': 3573374,
#  'main': {'humidity': 69,
#           'pressure': 1021,
#           'temp': 78.24,
#           'temp_max': 78.8,
#           'temp_min': 78.01},
#  'name': 'The Valley',
#  'sys': {'country': 'AI',
#          'id': 8801,
#          'message': 0.0048,
#          'sunrise': 1554285895,
#          'sunset': 1554330352,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 11.41}}
#
# 75
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -4.22, 'lon': 142.82},
#  'dt': 1554341445,
#  'id': 2100933,
#  'main': {'grnd_level': 993.59,
#           'humidity': 86,
#           'pressure': 1009.44,
#           'sea_level': 1009.44,
#           'temp': 81.63,
#           'temp_max': 81.63,
#           'temp_min': 81.63},
#  'name': 'Ambunti',
#  'rain': {'3h': 0.135},
#  'sys': {'country': 'PG',
#          'message': 0.0038,
#          'sunrise': 1554323401,
#          'sunset': 1554366809},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 132.501, 'speed': 2.95}}
#
# 76
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -26.79, 'lon': -60.44},
#  'dt': 1554341446,
#  'id': 3840300,
#  'main': {'grnd_level': 995.27,
#           'humidity': 94,
#           'pressure': 1005.52,
#           'sea_level': 1005.52,
#           'temp': 71.82,
#           'temp_max': 71.82,
#           'temp_min': 71.82},
#  'name': 'Presidencia Roque Saenz Pena',
#  'sys': {'country': 'AR',
#          'message': 0.0043,
#          'sunrise': 1554286311,
#          'sunset': 1554328679},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70.0015, 'speed': 4.63}}
#
# 77
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1554339600,
#  'id': 4031574,
#  'main': {'humidity': 68,
#           'pressure': 1015,
#           'temp': 26.6,
#           'temp_max': 26.6,
#           'temp_min': 26.6},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'id': 8875,
#          'message': 0.0043,
#          'sunrise': 1554395941,
#          'sunset': 1554445942,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'gust': 12, 'speed': 15.66}}
#
# 78
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 72.79, 'lon': -56.15},
#  'dt': 1554341206,
#  'id': 3418910,
#  'main': {'grnd_level': 998.21,
#           'humidity': 95,
#           'pressure': 1001.4,
#           'sea_level': 1001.4,
#           'temp': 17.78,
#           'temp_max': 17.78,
#           'temp_min': 17.78},
#  'name': 'Upernavik',
#  'sys': {'country': 'GL',
#          'message': 0.0032,
#          'sunrise': 1554280000,
#          'sunset': 1554332932},
#  'weather': [{'description': 'overcast clouds',
# ...
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 223.001, 'speed': 1.5}}
#
# 599
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.58, 'lon': -70.99},
#  'dt': 1554339600,
#  'id': 3871286,
#  'main': {'humidity': 82,
#           'pressure': 1017,
#           'temp': 59,
#           'temp_max': 59,
#           'temp_min': 59},
#  'name': 'San Fernando',
#  'sys': {'country': 'CL',
#          'id': 8497,
#          'message': 0.0035,
#          'sunrise': 1554289059,
#          'sunset': 1554330994,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 3.36}}
#
# 600
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 64.86, 'lon': -147.8},
#  'dt': 1554341106,
#  'id': 5859699,
#  'main': {'humidity': 32,
#           'pressure': 1017,
#           'temp': 24.78,
#           'temp_max': 30.2,
#           'temp_min': 21},
#  'name': 'College',
#  'sys': {'country': 'US',
#          'id': 7684,
#          'message': 0.0128,
#          'sunrise': 1554303607,
#          'sunset': 1554353308,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'gust': 11.8, 'speed': 20.8}}
#
# 601
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.77, 'lon': -9.06},
#  'dt': 1554341326,
#  'id': 3115824,
#  'main': {'humidity': 100,
#           'pressure': 1009,
#           'temp': 39.88,
#           'temp_max': 48,
#           'temp_min': 33.01},
#  'name': 'Muros',
#  'sys': {'country': 'ES',
#          'id': 6434,
#          'message': 0.0044,
#          'sunrise': 1554358427,
#          'sunset': 1554404670,
#          'type': 1},
#  'visibility': 2500,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 333.501, 'speed': 11.77}}
#
# 602
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -0.46, 'lon': 39.64},
#  'dt': 1554341588,
#  'id': 197745,
#  'main': {'grnd_level': 988.95,
#           'humidity': 87,
#           'pressure': 1010.96,
#           'sea_level': 1010.96,
#           'temp': 78.03,
#           'temp_max': 78.03,
#           'temp_min': 78.03},
#  'name': 'Garissa',
#  'sys': {'country': 'KE',
#          'message': 0.0049,
#          'sunrise': 1554348073,
#          'sunset': 1554391652},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 171.501, 'speed': 7.09}}
#
# 603
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -7.95, 'lon': 110.28},
#  'dt': 1554341124,
#  'id': 1650434,
#  'main': {'grnd_level': 982.21,
#           'humidity': 94,
#           'pressure': 1012.24,
#           'sea_level': 1012.24,
#           'temp': 76.01,
#           'temp_max': 76.01,
#           'temp_min': 76.01},
#  'name': 'Bambanglipuro',
#  'sys': {'country': 'ID',
#          'message': 0.0038,
#          'sunrise': 1554331295,
#          'sunset': 1554374531},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 323.001, 'speed': 3.15}}
#
# 604
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -6.24, 'lon': -42.69},
#  'dt': 1554341589,
#  'id': 3390700,
#  'main': {'grnd_level': 988.71,
#           'humidity': 96,
#           'pressure': 1012.2,
#           'sea_level': 1012.2,
#           'temp': 71.82,
#           'temp_max': 71.82,
#           'temp_min': 71.82},
#  'name': 'Regeneracao',
#  'sys': {'country': 'BR',
#          'message': 0.0038,
#          'sunrise': 1554281573,
#          'sunset': 1554324899},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 4.50146, 'speed': 4.97}}
#
# 605
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 16.99, 'lon': -99.26},
#  'dt': 1554339000,
#  'id': 3532499,
#  'main': {'humidity': 74,
#           'pressure': 1013,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Tecoanapa',
#  'sys': {'country': 'MX',
#          'id': 7103,
#          'message': 0.0038,
#          'sunrise': 1554294610,
#          'sunset': 1554339010,
#          'type': 1},
#  'visibility': 11265,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'speed': 8.05}}
#
# 606
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 40.06, 'lon': -8.63},
#  'dt': 1554341502,
#  'id': 2733851,
#  'main': {'humidity': 70,
#           'pressure': 1010,
#           'temp': 45.01,
#           'temp_max': 48.2,
#           'temp_min': 37.99},
#  'name': 'Soure',
#  'sys': {'country': 'PT',
#          'id': 6896,
#          'message': 0.0033,
#          'sunrise': 1554358449,
#          'sunset': 1554404442,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 6.93}}
#
# 607
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -13.61, 'lon': 29.4},
#  'dt': 1554341589,
#  'id': 906221,
#  'main': {'grnd_level': 873.27,
#           'humidity': 63,
#           'pressure': 1013.32,
#           'sea_level': 1013.32,
#           'temp': 60.03,
#           'temp_max': 60.03,
#           'temp_min': 60.03},
#  'name': 'Mkushi',
#  'sys': {'country': 'ZM',
#          'message': 0.0035,
#          'sunrise': 1554350838,
#          'sunset': 1554393802},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 111.001, 'speed': 8.43}}
#
# 608
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.12, 'lon': -88.54},
#  'dt': 1554341568,
#  'id': 4237727,
#  'main': {'humidity': 43,
#           'pressure': 1024,
#           'temp': 55.56,
#           'temp_max': 59,
#           'temp_min': 51.8},
#  'name': 'Effingham',
#  'sys': {'country': 'US',
#          'id': 2725,
#          'message': 0.0047,
#          'sunrise': 1554291341,
#          'sunset': 1554337134,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 5.82}}
#
# 609
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 26.25, 'lon': 105.93},
#  'dt': 1554341590,
#  'id': 1817968,
#  'main': {'grnd_level': 871.03,
#           'humidity': 93,
#           'pressure': 1017.8,
#           'sea_level': 1017.8,
#           'temp': 52.83,
#           'temp_max': 52.83,
#           'temp_min': 52.83},
#  'name': 'Anshun',
#  'rain': {'3h': 0.5925},
#  'sys': {'country': 'CN',
#          'message': 0.0034,
#          'sunrise': 1554331483,
#          'sunset': 1554376430},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 32.5015, 'speed': 6.08}}
#
# 610
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 13.47, 'lon': 22.2},
#  'dt': 1554341352,
#  'id': 245669,
#  'main': {'grnd_level': 918.53,
#           'humidity': 23,
#           'pressure': 1009.08,
#           'sea_level': 1009.08,
#           'temp': 69.44,
#           'temp_max': 69.44,
#           'temp_min': 69.44},
#  'name': 'Adre',
#  'sys': {'country': 'TD',
#          'message': 0.0036,
#          'sunrise': 1554351921,
#          'sunset': 1554396174},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 44.0015, 'speed': 8.75}}
#
# 611
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 612
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -36.72, 'lon': -73.12},
#  'dt': 1554339600,
#  'id': 3870282,
#  'main': {'humidity': 100,
#           'pressure': 1017,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Talcahuano',
#  'sys': {'country': 'CL',
#          'id': 8499,
#          'message': 0.0037,
#          'sunrise': 1554289636,
#          'sunset': 1554331439,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 330, 'speed': 10.29}}
#
# 613
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 4.42, 'lon': -7.36},
#  'dt': 1554341341,
#  'id': 2281120,
#  'main': {'grnd_level': 1009.81,
#           'humidity': 100,
#           'pressure': 1011.04,
#           'sea_level': 1011.04,
#           'temp': 82.58,
#           'temp_max': 82.58,
#           'temp_min': 82.58},
#  'name': 'Tabou',
#  'sys': {'country': 'CI',
#          'message': 0.0033,
#          'sunrise': 1554359236,
#          'sunset': 1554403045},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 263.001, 'speed': 11.43}}
#
# 614
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -7.96, 'lon': 145.78},
#  'dt': 1554341591,
#  'id': 2094144,
#  'main': {'grnd_level': 968.47,
#           'humidity': 82,
#           'pressure': 1008.04,
#           'sea_level': 1008.04,
#           'temp': 84.6,
#           'temp_max': 84.6,
#           'temp_min': 84.6},
#  'name': 'Kerema',
#  'rain': {'3h': 1.145},
#  'sys': {'country': 'PG',
#          'message': 0.0031,
#          'sunrise': 1554322775,
#          'sunset': 1554366014},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 243.001, 'speed': 2.73}}
#
# 615
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 41.71, 'lon': 22.85},
#  'dt': 1554341240,
#  'id': 792656,
#  'main': {'humidity': 78,
#           'pressure': 1015,
#           'temp': 42.01,
#           'temp_max': 42.01,
#           'temp_min': 42.01},
#  'name': 'Berovo',
#  'rain': {'3h': 0.0025},
#  'sys': {'country': 'MK',
#          'id': 2000504,
#          'message': 0.0036,
#          'sunrise': 1554350827,
#          'sunset': 1554396956,
#          'type': 3},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 148.501, 'speed': 2.17}}
#
# 616
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 4.89, 'lon': -1.75},
#  'dt': 1554341343,
#  'id': 2294915,
#  'main': {'grnd_level': 1007.41,
#           'humidity': 100,
#           'pressure': 1010.52,
#           'sea_level': 1010.52,
#           'temp': 82.31,
#           'temp_max': 82.31,
#           'temp_min': 82.31},
#  'name': 'Takoradi',
#  'sys': {'country': 'GH',
#          'message': 0.0035,
#          'sunrise': 1554357878,
#          'sunset': 1554401710},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 243.001, 'speed': 9.53}}
#
# 617
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 50.7, 'lon': 3.14},
#  'dt': 1554341578,
#  'id': 2991302,
#  'main': {'humidity': 93,
#           'pressure': 998,
#           'temp': 33.94,
#           'temp_max': 37.4,
#           'temp_min': 30.99},
#  'name': 'Mouvaux',
#  'sys': {'country': 'FR',
#          'id': 6559,
#          'message': 0.0048,
#          'sunrise': 1554355056,
#          'sunset': 1554402186,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'speed': 2.24}}
#
# 618
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 48.41, 'lon': -89.26},
#  'dt': 1554341294,
#  'id': 6166142,
#  'main': {'humidity': 39,
#           'pressure': 1023,
#           'temp': 29.21,
#           'temp_max': 30,
#           'temp_min': 28.4},
#  'name': 'Thunder Bay',
#  'sys': {'country': 'CA',
#          'id': 906,
#          'message': 0.005,
#          'sunrise': 1554291068,
#          'sunset': 1554337753,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 5.82}}
#
# 619
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 62.1, 'lon': 126.7},
#  'dt': 1554341416,
#  'id': 2026861,
#  'main': {'grnd_level': 980.95,
#           'humidity': 66,
#           'pressure': 1012.88,
#           'sea_level': 1012.88,
#           'temp': 37.53,
#           'temp_max': 37.53,
#           'temp_min': 37.53},
#  'name': 'Berdigestyakh',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1554324445,
#          'sunset': 1554373501},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 118.501, 'speed': 3.74}}
#
# 620
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 621
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -17.23, 'lon': -67.92},
#  'dt': 1554341593,
#  'id': 3908339,
#  'main': {'grnd_level': 638.31,
#           'humidity': 100,
#           'pressure': 1011.64,
#           'sea_level': 1011.64,
#           'temp': 42.84,
#           'temp_max': 42.84,
#           'temp_min': 42.84},
#  'name': 'Patacamaya',
#  'rain': {'3h': 2.55},
#  'sys': {'country': 'BO',
#          'message': 0.0143,
#          'sunrise': 1554287874,
#          'sunset': 1554330706},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 243.501, 'speed': 3.96}}
#
# 622
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 42.73, 'lon': 124.72},
#  'dt': 1554341593,
#  'id': 2033866,
#  'main': {'grnd_level': 961.67,
#           'humidity': 38,
#           'pressure': 1000.88,
#           'sea_level': 1000.88,
#           'temp': 57.6,
#           'temp_max': 57.6,
#           'temp_min': 57.6},
#  'name': 'Xifeng',
#  'sys': {'country': 'CN',
#          'message': 0.0042,
#          'sunrise': 1554326360,
#          'sunset': 1554372536},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 248.501, 'speed': 15.93}}
#
# 623
# {'cod': '404', 'message': 'city not found'}
# Data not found... skipping.
# ------------
# 624
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 27.71, 'lon': 85.32},
#  'dt': 1554340800,
#  'id': 1283240,
#  'main': {'humidity': 82,
#           'pressure': 1018,
#           'temp': 62.6,
#           'temp_max': 62.6,
#           'temp_min': 62.6},
#  'name': 'Kathmandu',
#  'sys': {'country': 'NP',
#          'id': 9201,
#          'message': 0.0042,
#          'sunrise': 1554336380,
#          'sunset': 1554381424,
#          'type': 1},
#  'visibility': 2500,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'speed': 2.24}}
#
# 625
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 41.67, 'lon': 25.61},
#  'dt': 1554340214,
#  'id': 726885,
#  'main': {'humidity': 55,
#           'pressure': 1016,
#           'temp': 45,
#           'temp_max': 45,
#           'temp_min': 45},
#  'name': 'Konevo',
#  'sys': {'country': 'BG',
#          'id': 2011943,
#          'message': 0.0053,
#          'sunrise': 1554350168,
#          'sunset': 1554396291,
#          'type': 3},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 45, 'gust': 1.34, 'speed': 1.01}}

# %%
cities_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 9 columns):
# City          626 non-null object
# Country       626 non-null object
# Date          626 non-null object
# Latitude      626 non-null object
# Longitude     626 non-null object
# Cloudiness    626 non-null object
# Max_Temp      626 non-null object
# Humidity      626 non-null object
# Wind_Speed    626 non-null object
# dtypes: object(9)
# memory usage: 44.1+ KB

# %%
cities_weather.tail()
# Out:
#            City Country        Date Latitude Longitude Cloudiness Max_Temp  \
# 621  patacamaya      BO  1554341593   -17.23    -67.92         92    42.84
# 622      xifeng      CN  1554341593    42.73    124.72         56     57.6
# 623    saleaula
# 624   kathmandu      NP  1554340800    27.71     85.32         75     62.6
# 625      konevo      BG  1554340214    41.67     25.61         32       45
#
#     Humidity Wind_Speed
# 621      100       3.96
# 622       38      15.93
# 623
# 624       82       2.24
# 625       55       1.01

# %%
# Drop rows with any empty cells
# cities_weather.dropna(axis=0, how='any', inplace=True)
# cities_weather

# %%
cities_weather.count()
# Out:
# City          626
# Country       626
# Date          626
# Latitude      626
# Longitude     626
# Cloudiness    626
# Max_Temp      626
# Humidity      626
# Wind_Speed    626
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_weather.head()
# Out:
#            City Country        Date Latitude Longitude Cloudiness Max_Temp  \
# 0          hilo      US  1554341122    19.71   -155.08         90     80.6
# 1        miyako      JP  1554341026    33.63    130.94         20       59
# 2      kushtagi      IN  1554341429    15.76     76.19         12    77.13
# 3    butaritari      KI  1554341255     3.07    172.79         88    78.26
# 4  punta arenas      CL  1554340948   -53.16    -70.91         75       41
#
#   Humidity Wind_Speed
# 0       61      14.99
# 1       50       6.93
# 2       62        6.2
# 3      100       2.48
# 4       65      21.92

# %%
cities_weather.to_csv('cities_weather.csv',index=False)

# %%
cities_weather.dtypes
# Out:
# City          object
# Country       object
# Date          object
# Latitude      object
# Longitude     object
# Cloudiness    object
# Max_Temp      object
# Humidity      object
# Wind_Speed    object
# dtype: object

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Max_Temp"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Max Temperature (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature (F)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_MTemp')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Humidity"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Humidity (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Humidity (%)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Cloudiness"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Cloudiness (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Cloudiness (%)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# plt.scatter(cities_weather["Latitude"],cities_weather["Wind_Speed"], marker = "o", color="blue", 
#             linewidth=1, markersize=5)
# plt.title("City Latitude vs. Wind Speed (04/02/2019)")
# plt.xlabel("Latitude")
# plt.ylabel("Wind Speed (mph)")
# plt.grid()
# plt.show()
# plt.savefig('Lat_vs_Wind_Speed')
